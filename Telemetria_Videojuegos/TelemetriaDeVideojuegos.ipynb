# %% [markdown]
# <a href="https://colab.research.google.com/github/AbnerJSV/THE_CORE_Trabajos_iA/blob/main/Telemetria_Videojuegos/TelemetriaDeVideojuegos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar la librería pandas para manipulación de datos
import pandas as pd

# Cargar el archivo CSV 'videojuegos_online_telemetria.csv' en un DataFrame de pandas.
# Consejo: Siempre es buena práctica verificar el encoding si el archivo CSV no se carga correctamente.
# Por ejemplo: pd.read_csv('archivo.csv', encoding='latin1')
df = pd.read_csv('videojuegos_online_telemetria.csv')

# Mostrar las primeras 5 filas del DataFrame para una primera inspección de los datos.
# Esto ayuda a entender la estructura y el tipo de datos presentes.
# Consejo: Después de cargar los datos, considera usar `df.info()` para ver los tipos de datos y los valores no nulos, y `df.describe()` para estadísticas descriptivas de columnas numéricas.
print('Primeras 5 filas del DataFrame:')
print(df.head())
# Out:
# Primeras 5 filas del DataFrame:
#   PlayerID   Age Region Platform PreferredGenre  SessionsPerWeek  \
# 0    P0001  22.0  LATAM       PC            RPG                3
# 1    P0002  21.0     EU       PC        Shooter                7
# 2    P0003  40.0  LATAM   Mobile        Shooter                3
# 3    P0004  37.0    NaN       PC        Shooter                0
# 4    P0005  28.0     EU  Console        Shooter                3
#
#    AvgSessionMinutes  DaysSinceLastLogin  PlayerLevel  MatchesPlayedLast30D  \
# 0               87.0                  11           59                    14
# 1              113.0                   0           45                    24
# 2               67.0                   3           68                    27
# 3               48.0                   9           40                    39
# 4               90.0                  15           51                    15
#
#    WinRate  InGamePurchase  FriendsInGame  UsesVoiceChat  \
# 0    0.481            7.38            3.0              1
# 1    0.475           11.56            8.0              1
# 2    0.341            0.42            6.0              1
# 3    0.225            8.83            NaN              1
# 4    0.454           23.86            0.0              0
#
#    AchievementsUnlocked  ReportsReceivedLast30D  Churn30D
# 0                    17                       0         0
# 1                    21                       2         0
# 2                    26                       1         0
# 3                    41                       2         0
# 4                    35                       1         1

# %%
# Contar el número de valores duplicados en la columna 'PlayerID'.
# 'duplicated()' devuelve una serie booleana indicando si cada fila es un duplicado.
# Por defecto, `keep='first'` marca como True las ocurrencias duplicadas excepto la primera.
# `.sum()` cuenta cuántos valores True hay, es decir, el número de duplicados.
num_duplicates = df['PlayerID'].duplicated().sum()

# Mostrar el resultado del conteo de duplicados.
if num_duplicates > 0:
    print(f"Se encontraron {num_duplicates} valores duplicados en la columna 'PlayerID'.")
    print("Las filas duplicadas (manteniendo la primera aparición) son:")
    # Mostrar solo las filas que son duplicados (excluyendo la primera ocurrencia).
    # Consejo: Es importante revisar estas filas para entender la naturaleza de los duplicados antes de eliminarlos.
    display(df[df['PlayerID'].duplicated(keep='first')])
else:
    print("No se encontraron valores duplicados en la columna 'PlayerID'.")
# Out:
# Se encontraron 8 valores duplicados en la columna 'PlayerID'.
# Las filas duplicadas (manteniendo la primera aparición) son:
#     PlayerID   Age Region Platform PreferredGenre  SessionsPerWeek  \
# 550    P0196  31.0  LATAM       PC            RPG                4
# 551    P0080  37.0    NaN       pc            RPG                1
# 552    P0481  40.0     EU       PC         Sports                2
# 553    P0110  20.0     EU  Console            RPG                1
# 554    P0523  27.0     EU       PC        Shooter                3
# 555    P0533  28.0     EU       pc  Battle Royale                4
# 556    P0085  30.0  LATAM       PC            RPG                4
# 557    P0369  29.0     EU       PC         Sports                2
#
#      AvgSessionMinutes  DaysSinceLastLogin  PlayerLevel  MatchesPlayedLast30D  \
# 550              127.0                   2           56                    33
# 551               89.0                   3           52                    23
# 552              111.0                   6           15                    30
# 553               97.0                  11           76                    12
# 554               91.0                   7           27                     3
# 555               87.0                   5            6                     0
# 556               33.0                  10           46                    20
# 557               96.0                   0           23                    34
#
#      WinRate  InGamePurchase  FriendsInGame  UsesVoiceChat  \
# 550    0.545           20.40            0.0              1
# 551    0.496            0.90            5.0              1
# 552    0.357            0.50           13.0              1
# 553    0.469           26.12            1.0              0
# 554    0.513            1.60           15.0              1
# 555    0.528            0.18            4.0              0
# 556    0.736            5.09            0.0              1
# 557    0.332           25.64           12.0              0
#
#      AchievementsUnlocked  ReportsReceivedLast30D  Churn30D
# 550                    28                       0         0
# 551                     0                       0         0
# 552                    22                       2         1
# 553                    19                       2         0
# 554                    27                       4         0
# 555                    10                       0         0
# 556                    46                       3         0
# 557                    36                       0         1

# %%
# Mostrar todas las filas que tienen valores duplicados en la columna 'PlayerID'.
# `keep=False` marca como True todas las ocurrencias de los duplicados, incluyendo la primera.
# Esto permite ver el grupo completo de filas que comparten un 'PlayerID' duplicado.
duplicated_rows = df[df['PlayerID'].duplicated(keep=False)]

# Verificar si se encontraron filas duplicadas y mostrarlas.
if not duplicated_rows.empty:
    print("Todas las filas con 'PlayerID' duplicados son:")
    # Consejo: Analizar estas filas es crucial para decidir cómo manejar los duplicados (ej. ¿cuál es la fila 'correcta' si hay inconsistencias?).
    display(duplicated_rows)
else:
    print("No se encontraron valores duplicados en la columna 'PlayerID'.")
# Out:
# Todas las filas con 'PlayerID' duplicados son:
#     PlayerID   Age Region Platform PreferredGenre  SessionsPerWeek  \
# 79     P0080  37.0    NaN       pc            RPG                1
# 84     P0085  30.0  LATAM       PC            RPG                4
# 109    P0110  20.0     EU  Console            RPG                1
# 195    P0196  31.0  LATAM       PC            RPG                4
# 368    P0369  29.0     EU       PC         Sports                2
# 480    P0481  40.0     EU       PC         Sports                2
# 522    P0523  27.0     EU       PC        Shooter                3
# 532    P0533  28.0     EU       pc  Battle Royale                4
# 550    P0196  31.0  LATAM       PC            RPG                4
# 551    P0080  37.0    NaN       pc            RPG                1
# 552    P0481  40.0     EU       PC         Sports                2
# 553    P0110  20.0     EU  Console            RPG                1
# 554    P0523  27.0     EU       PC        Shooter                3
# 555    P0533  28.0     EU       pc  Battle Royale                4
# 556    P0085  30.0  LATAM       PC            RPG                4
# 557    P0369  29.0     EU       PC         Sports                2
#
#      AvgSessionMinutes  DaysSinceLastLogin  PlayerLevel  MatchesPlayedLast30D  \
# 79                89.0                   3           52                    23
# 84                33.0                  10           46                    20
# 109               97.0                  11           76                    12
# 195              127.0                   2           56                    33
# 368               96.0                   0           23                    34
# 480              111.0                   6           15                    30
# 522               91.0                   7           27                     3
# 532               87.0                   5            6                     0
# 550              127.0                   2           56                    33
# 551               89.0                   3           52                    23
# 552              111.0                   6           15                    30
# 553               97.0                  11           76                    12
# 554               91.0                   7           27                     3
# 555               87.0                   5            6                     0
# 556               33.0                  10           46                    20
# 557               96.0                   0           23                    34
#
#      WinRate  InGamePurchase  FriendsInGame  UsesVoiceChat  \
# 79     0.496            0.90            5.0              1
# 84     0.736            5.09            0.0              1
# 109    0.469           26.12            1.0              0
# 195    0.545           20.40            0.0              1
# 368    0.332           25.64           12.0              0
# 480    0.357            0.50           13.0              1
# 522    0.513            1.60           15.0              1
# 532    0.528            0.18            4.0              0
# 550    0.545           20.40            0.0              1
# 551    0.496            0.90            5.0              1
# 552    0.357            0.50           13.0              1
# 553    0.469           26.12            1.0              0
# 554    0.513            1.60           15.0              1
# 555    0.528            0.18            4.0              0
# 556    0.736            5.09            0.0              1
# 557    0.332           25.64           12.0              0
#
#      AchievementsUnlocked  ReportsReceivedLast30D  Churn30D
# 79                      0                       0         0
# 84                     46                       3         0
# 109                    19                       2         0
# 195                    28                       0         0
# 368                    36                       0         1
# 480                    22                       2         1
# 522                    27                       4         0
# 532                    10                       0         0
# 550                    28                       0         0
# 551                     0                       0         0
# 552                    22                       2         1
# 553                    19                       2         0
# 554                    27                       4         0
# 555                    10                       0         0
# 556                    46                       3         0
# 557                    36                       0         1

# %%
# Eliminar filas duplicadas basándose únicamente en la columna 'PlayerID'.
# `subset=['PlayerID']` especifica que la búsqueda de duplicados se haga solo en esta columna.
# `keep='first'` asegura que la primera ocurrencia de cada 'PlayerID' se mantenga y las siguientes se eliminen.
df_cleaned = df.drop_duplicates(subset=['PlayerID'], keep='first')

# Mostrar el número de filas antes y después de la eliminación para verificar la operación.
print(f"Filas antes de eliminar duplicados: {df.shape[0]}")
print(f"Filas después de eliminar duplicados: {df_cleaned.shape[0]}")

# Actualizar el DataFrame original `df` con el DataFrame limpio `df_cleaned`.
# Se utiliza `.copy()` para asegurar que `df` sea una copia independiente y evitar `SettingWithCopyWarning` en futuras operaciones.
df = df_cleaned.copy()

# Verificar si aún existen duplicados en 'PlayerID' para confirmar que la eliminación fue exitosa.
num_remaining_duplicates = df['PlayerID'].duplicated().sum()
if num_remaining_duplicates == 0:
    print("\nSe han eliminado todos los duplicados en la columna 'PlayerID'.")
else:
    print(f"\nTodavía quedan {num_remaining_duplicates} duplicados en 'PlayerID'.")
# Consejo: Siempre verifica el éxito de la operación de limpieza de datos.
# Out:
# Filas antes de eliminar duplicados: 558
# Filas después de eliminar duplicados: 550
#
# Se han eliminado todos los duplicados en la columna 'PlayerID'.

# %% [markdown]
# ### Manejo de valores faltantes en la columna 'Age'
#
# Vamos a calcular la mediana de la columna 'Age' y usarla para rellenar los valores faltantes (NaN) en esta columna.

# %%
# Calcular la mediana de la columna 'Age'. La mediana es robusta a valores atípicos (outliers).
median_age = df['Age'].median()
print(f"Mediana de la columna 'Age': {median_age}")

# Rellenar los valores faltantes (NaN) en la columna 'Age' con la mediana calculada.
# `df.loc[:, 'Age']` se usa para asegurar la modificación en el DataFrame original y evitar advertencias.
df.loc[:, 'Age'] = df['Age'].fillna(median_age)

# Verificar si quedan valores NaN en la columna 'Age' después de la imputación.
print(f"\nNúmero de valores NaN en la columna 'Age' después de rellenar: {df['Age'].isnull().sum()}")

# Mostrar las primeras filas del DataFrame para verificar visualmente el cambio en la columna 'Age'.
print("\nPrimeras 5 filas del DataFrame con 'Age' rellenado:")
print(df.head())

# Mostrar la información del DataFrame (tipos de datos, conteo de no nulos) para confirmar el estado de 'Age'.
print("\nInformación del DataFrame después de rellenar 'Age':")
# Consejo: `df.info()` es una excelente herramienta para verificar rápidamente si las columnas tienen valores nulos y sus tipos de datos.
df.info()
# Out:
# Mediana de la columna 'Age': 28.0
#
# Número de valores NaN en la columna 'Age' después de rellenar: 0
#
# Primeras 5 filas del DataFrame con 'Age' rellenado:
#   PlayerID   Age Region Platform PreferredGenre  SessionsPerWeek  \
# 0    P0001  22.0  LATAM       PC            RPG                3
# 1    P0002  21.0     EU       PC        Shooter                7
# 2    P0003  40.0  LATAM   Mobile        Shooter                3
# 3    P0004  37.0    NaN       PC        Shooter                0
# 4    P0005  28.0     EU  Console        Shooter                3
#
#    AvgSessionMinutes  DaysSinceLastLogin  PlayerLevel  MatchesPlayedLast30D  \
# 0               87.0                  11           59                    14
# 1              113.0                   0           45                    24
# 2               67.0                   3           68                    27
# 3               48.0                   9           40                    39
# 4               90.0                  15           51                    15
#
#    WinRate  InGamePurchase  FriendsInGame  UsesVoiceChat  \
# 0    0.481            7.38            3.0              1
# 1    0.475           11.56            8.0              1
# 2    0.341            0.42            6.0              1
# 3    0.225            8.83            NaN              1
# 4    0.454           23.86            0.0              0
#
#    AchievementsUnlocked  ReportsReceivedLast30D  Churn30D
# 0                    17                       0         0
# 1                    21                       2         0
# 2                    26                       1         0
# 3                    41                       2         0
# 4                    35                       1         1
#
# Información del DataFrame después de rellenar 'Age':
# <class 'pandas.core.frame.DataFrame'>
# Index: 550 entries, 0 to 549
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PlayerID                550 non-null    object
#  1   Age                     550 non-null    float64
#  2   Region                  421 non-null    object
#  3   Platform                550 non-null    object
#  4   PreferredGenre          550 non-null    object
#  5   SessionsPerWeek         550 non-null    int64
#  6   AvgSessionMinutes       538 non-null    float64
#  7   DaysSinceLastLogin      550 non-null    int64
#  8   PlayerLevel             550 non-null    int64
#  9   MatchesPlayedLast30D    550 non-null    int64
#  10  WinRate                 538 non-null    float64
#  11  InGamePurchase          538 non-null    float64
#  12  FriendsInGame           538 non-null    float64
#  13  UsesVoiceChat           550 non-null    int64
#  14  AchievementsUnlocked    550 non-null    int64
#  15  ReportsReceivedLast30D  550 non-null    int64
#  16  Churn30D                550 non-null    int64
# dtypes: float64(5), int64(8), object(4)
# memory usage: 77.3+ KB

# %%
# Mostrar el conteo de valores únicos en la columna 'Region' ANTES de realizar cambios.
# `dropna=False` incluye los valores NaN en el conteo, lo cual es útil para identificar faltantes.
print('Valores de la columna Region antes de los cambios:')
print(df['Region'].value_counts(dropna=False))

# Rellenar los valores NaN (faltantes) en la columna 'Region' con la cadena 'USA'.
# Esto asume que los valores faltantes corresponden a esta región por alguna razón de negocio o default.
df['Region'] = df['Region'].fillna('USA')

# Reemplazar la cadena 'Europe' por 'EU' en la columna 'Region' para estandarizar los nombres.
# Consejo: Es fundamental estandarizar las categorías en columnas de tipo 'object' para evitar inconsistencias.
df['Region'] = df['Region'].replace('Europe', 'EU')

# Mostrar el conteo de valores únicos en la columna 'Region' DESPUÉS de realizar los cambios.
print('\nValores de la columna Region después de los cambios:')
print(df['Region'].value_counts(dropna=False))

# Mostrar los valores únicos (distintos) presentes en la columna 'Region' para verificar la estandarización.
print('\nRegiones distintas en la columna Region después de los cambios:')
print(df['Region'].unique())
# Consejo: Para columnas categóricas, siempre revisa los valores únicos y sus conteos para detectar errores de entrada o inconsistencias.
# Out:
# Valores de la columna Region antes de los cambios:
# Region
# EU        211
# NaN       129
# APAC       81
# LATAM      75
# Europe     54
# Name: count, dtype: int64
#
# Valores de la columna Region después de los cambios:
# Region
# EU       265
# USA      129
# APAC      81
# LATAM     75
# Name: count, dtype: int64
#
# Regiones distintas en la columna Region después de los cambios:
# ['LATAM' 'EU' 'USA' 'APAC']

# %%
# Obtener y mostrar los valores únicos de la columna 'Region' para verificar la limpieza.
distinct_regions = df['Region'].unique()
print(f"Regiones distintas en la columna 'Region': {distinct_regions}")

# Contar el número de valores NaN (faltantes) en la columna 'Region'.
# Esto confirma que los valores NaN fueron manejados correctamente.
num_nan_regions = df['Region'].isnull().sum()
print(f"Número de valores NaN (faltantes) en la columna 'Region': {num_nan_regions}")

# Informar si se encontraron valores NaN (aunque en este punto no deberían haber).
if num_nan_regions > 0:
    print("Estos valores 'nan' representan datos faltantes que pandas ha detectado o convertido.")

# Mostrar el conteo de valores por cada región, incluyendo NaN (si los hubiera, pero se espera 0).
# Esto sirve como una verificación final de la distribución de las categorías.
print("\nConteo de valores por cada región (incluyendo NaN):")
print(df['Region'].value_counts(dropna=False))
# Consejo: Siempre valida los resultados después de realizar operaciones de limpieza en columnas categóricas.
# Out:
# Regiones distintas en la columna 'Region': ['LATAM' 'EU' 'USA' 'APAC']
# Número de valores NaN (faltantes) en la columna 'Region': 0
#
# Conteo de valores por cada región (incluyendo NaN):
# Region
# EU       265
# USA      129
# APAC      81
# LATAM     75
# Name: count, dtype: int64

# %%
# Contar el número de plataformas únicas antes de cualquier cambio.
num_unique_platforms = df['Platform'].nunique()
print(f"Número de plataformas diferentes en la columna 'Platform': {num_unique_platforms}")

# Mostrar los nombres de las plataformas únicas antes de la estandarización.
print("Nombres de las plataformas únicas antes del cambio:")
print(df['Platform'].unique())

# Reemplazar la cadena 'pc' (minúscula) con 'PC' (mayúscula) para estandarizar los nombres de las plataformas.
# Esto es común en la limpieza de datos para manejar inconsistencias de capitalización.
df['Platform'] = df['Platform'].replace('pc', 'PC')

# Mostrar los nombres de las plataformas únicas después del cambio para verificar la estandarización.
print("\nNombres de las plataformas únicas después del cambio:")
print(df['Platform'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'Platform'.
num_nan_platforms = df['Platform'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'Platform': {num_nan_platforms}")

# Informar si se encontraron valores NaN (se espera que no haya en este caso).
if num_nan_platforms > 0:
    print("Estos valores 'nan' representan datos faltantes en la columna 'Platform' (y no hay en este caso).")
# Consejo: Siempre busca y corrige inconsistencias de capitalización, espacios extra o errores tipográficos en columnas categóricas.
# Out:
# Número de plataformas diferentes en la columna 'Platform': 4
# Nombres de las plataformas únicas antes del cambio:
# ['PC' 'Mobile' 'Console' 'pc']
#
# Nombres de las plataformas únicas después del cambio:
# ['PC' 'Mobile' 'Console']
#
# Número de valores NaN (faltantes) en la columna 'Platform': 0

# %%
# Mostrar los valores distintos (únicos) presentes en la columna 'PreferredGenre'.
# Esto ayuda a entender la variedad de géneros y detectar posibles errores o inconsistencias.
print("Valores distintos en 'PreferredGenre':")
print(df['PreferredGenre'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'PreferredGenre'.
num_nan_preferred_genre = df['PreferredGenre'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'PreferredGenre': {num_nan_preferred_genre}")

# Informar si se encontraron valores NaN.
if num_nan_preferred_genre > 0:
    print("Estos valores 'nan' representan datos faltantes en la columna 'PreferredGenre'.")
# Consejo: Si hubiera NaN, una estrategia sería imputarlos con la moda (el género más frecuente) o 'Desconocido'.

# Mostrar el conteo de valores por cada género preferido, incluyendo NaN (si los hubiera).
# Esto proporciona una visión de la distribución de los géneros.
print("\nConteo de valores por cada género preferido (incluyendo NaN):")
print(df['PreferredGenre'].value_counts(dropna=False))
# Out:
# Valores distintos en 'PreferredGenre':
# ['RPG' 'Shooter' 'Strategy' 'Battle Royale' 'MOBA' 'Sports']
#
# Número de valores NaN (faltantes) en la columna 'PreferredGenre': 0
#
# Conteo de valores por cada género preferido (incluyendo NaN):
# PreferredGenre
# Battle Royale    100
# Strategy          93
# Sports            93
# RPG               92
# MOBA              87
# Shooter           85
# Name: count, dtype: int64

# %%
# Mostrar los valores distintos (únicos) presentes en la columna 'SessionsPerWeek'.
# Esto permite identificar el rango y la granularidad de los datos de sesiones por semana.
print("Valores distintos en 'SessionsPerWeek':")
print(df['SessionsPerWeek'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'SessionsPerWeek'.
num_nan_sessions_per_week = df['SessionsPerWeek'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'SessionsPerWeek': {num_nan_sessions_per_week}")

# Informar si se encontraron valores NaN.
if num_nan_sessions_per_week > 0:
    print("Estos valores 'nan' representan datos faltantes en la columna 'SessionsPerWeek'.")
# Consejo: Si hubiera NaN, la imputación con la mediana o la moda sería apropiada para una variable de conteo como esta.

# Mostrar el conteo de valores por cada número de sesiones por semana, incluyendo NaN (si los hubiera).
# Esto ofrece una vista de la distribución de la frecuencia de juego.
print("\nConteo de valores por cada SessionsPerWeek (incluyendo NaN):")
print(df['SessionsPerWeek'].value_counts(dropna=False))
# Out:
# Valores distintos en 'SessionsPerWeek':
# [ 3  7  0  5  4  6  8  2 10  1  9]
#
# Número de valores NaN (faltantes) en la columna 'SessionsPerWeek': 0
#
# Conteo de valores por cada SessionsPerWeek (incluyendo NaN):
# SessionsPerWeek
# 4     106
# 3     104
# 5     101
# 6      86
# 7      51
# 2      36
# 1      27
# 8      24
# 0       6
# 9       5
# 10      4
# Name: count, dtype: int64

# %%
# Mostrar los valores distintos en la columna 'AvgSessionMinutes' ANTES de rellenar los NaN.
# Esto permite ver la presencia de NaN antes de la imputación.
print("Valores distintos en 'AvgSessionMinutes' antes de rellenar NaN:")
print(df['AvgSessionMinutes'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'AvgSessionMinutes' ANTES de la imputación.
num_nan_avg_session_minutes_before = df['AvgSessionMinutes'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'AvgSessionMinutes' ANTES de rellenar: {num_nan_avg_session_minutes_before}")

# Calcular la mediana de 'AvgSessionMinutes'. La mediana es preferible a la media si la distribución es asimétrica (skewed).
median_avg_session_minutes = df['AvgSessionMinutes'].median()
print(f"Mediana calculada para 'AvgSessionMinutes': {median_avg_session_minutes}")

# Rellenar los valores NaN en la columna 'AvgSessionMinutes' con la mediana calculada.
df['AvgSessionMinutes'] = df['AvgSessionMinutes'].fillna(median_avg_session_minutes)

# Mostrar los valores distintos en 'AvgSessionMinutes' DESPUÉS de rellenar los NaN para verificar la imputación.
print("\nValores distintos en 'AvgSessionMinutes' DESPUÉS de rellenar NaN:")
print(df['AvgSessionMinutes'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'AvgSessionMinutes' DESPUÉS de la imputación.
num_nan_avg_session_minutes_after = df['AvgSessionMinutes'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'AvgSessionMinutes' DESPUÉS de rellenar: {num_nan_avg_session_minutes_after}")

# Confirmar si todos los valores NaN han sido rellenados.
if num_nan_avg_session_minutes_after == 0:
    print("Todos los valores NaN en 'AvgSessionMinutes' han sido rellenados con éxito.")

# Mostrar el conteo de valores por cada 'AvgSessionMinutes', incluyendo NaN (si los hubiera, se espera 0).
# Esto permite una verificación final de la distribución de los datos.
print("\nConteo de valores por cada AvgSessionMinutes (incluyendo NaN después de rellenar):")
print(df['AvgSessionMinutes'].value_counts(dropna=False))
# Out:
# Valores distintos en 'AvgSessionMinutes' antes de rellenar NaN:
# [ 87. 113.  67.  48.  90.  32.  25.  66.  70.  72. 109.  nan 138. 119.
#  151.  71.  76.  57. 123. 102.  44. 420. 101.  59. 116.  63. 103.  69.
#   99. 105.  94.  51.  55.  45. 122. 510.  10. 124. 114.  85.  86.  88.
#   77.  47.  92.  41.  43.  15.  78.  58.  65.  75.  96.  38.  61.  89.
#   50.  98.  84.  33.  40.  73.  83.  49.  80. 104. 120.  81. 600.  64.
#   97.  56.  68.  62.  30. 125. 154.  91.  79.  82.  52. 110.  74.  53.
#   34.  95.  93. 100. 127. 117. 108.  11.  21.  46. 107.  27. 106.  22.
#   60. 112. 115.  54.  39. 145. 139. 137. 126.  19. 111. 134.  14.  36.
#   23.  37.  31.  26. 118.]
#
# Número de valores NaN (faltantes) en la columna 'AvgSessionMinutes' ANTES de rellenar: 12
# Mediana calculada para 'AvgSessionMinutes': 76.0
#
# Valores distintos en 'AvgSessionMinutes' DESPUÉS de rellenar NaN:
# [ 87. 113.  67.  48.  90.  32.  25.  66.  70.  72. 109.  76. 138. 119.
#  151.  71.  57. 123. 102.  44. 420. 101.  59. 116.  63. 103.  69.  99.
#  105.  94.  51.  55.  45. 122. 510.  10. 124. 114.  85.  86.  88.  77.
#   47.  92.  41.  43.  15.  78.  58.  65.  75.  96.  38.  61.  89.  50.
#   98.  84.  33.  40.  73.  83.  49.  80. 104. 120.  81. 600.  64.  97.
#   56.  68.  62.  30. 125. 154.  91.  79.  82.  52. 110.  74.  53.  34.
#   95.  93. 100. 127. 117. 108.  11.  21.  46. 107.  27. 106.  22.  60.
#  112. 115.  54.  39. 145. 139. 137. 126.  19. 111. 134.  14.  36.  23.
#   37.  31.  26. 118.]
#
# Número de valores NaN (faltantes) en la columna 'AvgSessionMinutes' DESPUÉS de rellenar: 0
# Todos los valores NaN en 'AvgSessionMinutes' han sido rellenados con éxito.
#
# Conteo de valores por cada AvgSessionMinutes (incluyendo NaN después de rellenar):
# AvgSessionMinutes
# 76.0     19
# 68.0     15
# 75.0     13
# 66.0     13
# 74.0     12
#          ..
# 23.0      1
# 37.0      1
# 31.0      1
# 26.0      1
# 118.0     1
# Name: count, Length: 116, dtype: int64

# %%
# Mostrar los valores distintos (únicos) presentes en la columna 'DaysSinceLastLogin'.
# Esto da una idea del comportamiento de inicio de sesión de los jugadores.
print("Valores distintos en 'DaysSinceLastLogin':")
print(df['DaysSinceLastLogin'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'DaysSinceLastLogin'.
num_nan_days_since_last_login = df['DaysSinceLastLogin'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'DaysSinceLastLogin': {num_nan_days_since_last_login}")

# Informar si se encontraron valores NaN.
if num_nan_days_since_last_login > 0:
    print("Estos valores 'nan' representan datos faltantes en la columna 'DaysSinceLastLogin'.")
# Consejo: Para una variable de conteo como esta, si hubiera NaN, la mediana o la moda serían buenas opciones de imputación.

# Mostrar el conteo de valores por cada 'DaysSinceLastLogin', incluyendo NaN (si los hubiera).
# Esto proporciona una distribución de cuánto tiempo ha pasado desde el último inicio de sesión.
print("\nConteo de valores por cada DaysSinceLastLogin (incluyendo NaN):")
print(df['DaysSinceLastLogin'].value_counts(dropna=False))
# Out:
# Valores distintos en 'DaysSinceLastLogin':
# [11  0  3  9 15 10  6 13 16  1  5  7 14  8  2 22 21  4 23 12 26 17 18 19
#  20 25 24]
#
# Número de valores NaN (faltantes) en la columna 'DaysSinceLastLogin': 0
#
# Conteo de valores por cada DaysSinceLastLogin (incluyendo NaN):
# DaysSinceLastLogin
# 0     97
# 10    38
# 9     36
# 6     34
# 5     32
# 7     32
# 11    31
# 3     29
# 8     28
# 12    24
# 4     23
# 13    21
# 1     19
# 14    18
# 15    15
# 2     15
# 16    12
# 17    12
# 18     8
# 22     6
# 21     6
# 20     4
# 19     4
# 23     2
# 25     2
# 26     1
# 24     1
# Name: count, dtype: int64

# %%
# Mostrar los valores distintos (únicos) presentes en la columna 'PlayerLevel'.
# Esto revela el rango de niveles de los jugadores en el dataset.
print("Valores distintos en 'PlayerLevel':")
print(df['PlayerLevel'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'PlayerLevel'.
num_nan_player_level = df['PlayerLevel'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'PlayerLevel': {num_nan_player_level}")

# Informar si se encontraron valores NaN y si no se encontraron.
if num_nan_player_level > 0:
    print("Estos valores 'nan' representan datos faltantes en la columna 'PlayerLevel'.")
# Consejo: Si hubiera NaN, la imputación con la mediana o la moda sería adecuada para una variable discreta como el nivel de jugador.
else:
    print("No se encontraron valores NaN en la columna 'PlayerLevel'.")

# Mostrar el conteo de valores por cada nivel de jugador, incluyendo NaN (si los hubiera).
# Esto ofrece una distribución de los niveles de los jugadores.
print("\nConteo de valores por cada nivel de jugador (incluyendo NaN):")
print(df['PlayerLevel'].value_counts(dropna=False))
# Out:
# Valores distintos en 'PlayerLevel':
# [59 45 68 40 51 33 41 30  1  9 36 46 31 32 47 48 54 27 50 39 26 14 43 42
#  61 24 71 35  5 15 29 16 37 49 67 17 44 38 10 58  7 79 62 52 20 63 22 57
#  60 23 11 73  4 76 56 28 19 21  2 25 55 13 69 66 34 65 86 74  8 53  6 18
#  12 72 70]
#
# Número de valores NaN (faltantes) en la columna 'PlayerLevel': 0
# No se encontraron valores NaN en la columna 'PlayerLevel'.
#
# Conteo de valores por cada nivel de jugador (incluyendo NaN):
# PlayerLevel
# 1     19
# 38    18
# 40    16
# 35    16
# 37    16
#       ..
# 57     1
# 65     1
# 74     1
# 72     1
# 70     1
# Name: count, Length: 75, dtype: int64

# %%
# Mostrar los valores distintos (únicos) presentes en la columna 'MatchesPlayedLast30D'.
# Esto da una idea de la actividad de juego de los usuarios en el último mes.
print("Valores distintos en 'MatchesPlayedLast30D':")
print(df['MatchesPlayedLast30D'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'MatchesPlayedLast30D'.
num_nan_matches_played = df['MatchesPlayedLast30D'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'MatchesPlayedLast30D': {num_nan_matches_played}")

# Informar si se encontraron valores NaN y si no se encontraron.
if num_nan_matches_played > 0:
    print("Estos valores 'nan' representan datos faltantes en la columna 'MatchesPlayedLast30D'.")
# Consejo: Si hubiera NaN, la imputación con la mediana o la moda podría ser considerada.
else:
    print("No se encontraron valores NaN en la columna 'MatchesPlayedLast30D'.")

# Mostrar el conteo de valores por cada 'MatchesPlayedLast30D', incluyendo NaN (si los hubiera).
# Esto proporciona una distribución de la cantidad de partidas jugadas.
print("\nConteo de valores por cada 'MatchesPlayedLast30D' (incluyendo NaN):")
print(df['MatchesPlayedLast30D'].value_counts(dropna=False))
# Out:
# Valores distintos en 'MatchesPlayedLast30D':
# [14 24 27 39 15 35 50 40 13 33 20 46  6 25 32 21 56 17  9 22 23 26  1 28
#   0 38 29 52 18  5 63 19 37 47  7 44 10  4 58 41 45 53 34  8 30 12 43 31
#  62 42 16 11  3 51 36 64 54 48 61  2 68 55 69 57]
#
# Número de valores NaN (faltantes) en la columna 'MatchesPlayedLast30D': 0
# No se encontraron valores NaN en la columna 'MatchesPlayedLast30D'.
#
# Conteo de valores por cada 'MatchesPlayedLast30D' (incluyendo NaN):
# MatchesPlayedLast30D
# 0     24
# 33    18
# 26    18
# 25    17
# 28    17
#       ..
# 63     1
# 62     1
# 61     1
# 68     1
# 69     1
# Name: count, Length: 64, dtype: int64

# %%
# Mostrar los valores distintos en la columna 'InGamePurchase' ANTES de rellenar los NaN.
print("Valores distintos en 'InGamePurchase' antes de rellenar NaN:")
print(df['InGamePurchase'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'InGamePurchase' ANTES de la imputación.
num_nan_in_game_purchase_before = df['InGamePurchase'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'InGamePurchase' ANTES de rellenar: {num_nan_in_game_purchase_before}")

# Calcular la media de 'InGamePurchase'. La media es una opción común para variables numéricas continuas como esta.
mean_in_game_purchase = df['InGamePurchase'].mean()
print(f"Media calculada para 'InGamePurchase': {mean_in_game_purchase:.2f}")

# Rellenar los valores NaN en la columna 'InGamePurchase' con la media calculada.
# Se utiliza `df.loc[:, 'InGamePurchase']` para asegurar la modificación en el DataFrame original y evitar advertencias.
df.loc[:, 'InGamePurchase'] = df['InGamePurchase'].fillna(mean_in_game_purchase)

# Mostrar los valores distintos en 'InGamePurchase' DESPUÉS de rellenar los NaN para verificar la imputación.
print("\nValores distintos en 'InGamePurchase' DESPUÉS de rellenar NaN:")
print(df['InGamePurchase'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de la imputación.
num_nan_in_game_purchase_after = df['InGamePurchase'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de rellenar: {num_nan_in_game_purchase_after}")

# Confirmar si todos los valores NaN han sido rellenados.
if num_nan_in_game_purchase_after == 0:
    print("Todos los valores NaN en 'InGamePurchase' han sido rellenados con éxito.")

# Mostrar el conteo de valores por cada 'InGamePurchase', incluyendo NaN (si los hubiera, se espera 0 después de rellenar).
print("\nConteo de valores por cada 'InGamePurchase' (incluyendo NaN después de rellenar):")
print(df['InGamePurchase'].value_counts(dropna=False))
# Out:
# Valores distintos en 'InGamePurchase' antes de rellenar NaN:
# [7.38000000e+00 1.15600000e+01 4.20000000e-01 8.83000000e+00
#  2.38600000e+01 3.23000000e+00 3.12000000e+00 1.00000000e-02
#  4.28100000e+01 7.13000000e+00 2.48000000e+00 1.35100000e+01
#  5.15000000e+00 7.14000000e+00 8.00000000e+00 5.84000000e+00
#  4.17000000e+00 4.77000000e+00 6.40000000e-01 2.04000000e+00
#  1.16000000e+00 1.90000000e-01 3.89900000e+01 4.11500000e+01
#  5.69000000e+00 4.78000000e+00 6.66000000e+00 2.84200000e+01
#  9.02000000e+00 1.18500000e+01 3.13000000e+00 2.41200000e+01
#  1.75800000e+01 2.29400000e+01 9.71000000e+00 1.32200000e+01
#  1.92800000e+01 1.71200000e+01 3.33000000e+00 1.05300000e+01
#  1.52100000e+01 1.04500000e+01 1.89800000e+01 2.14000000e+00
#  6.93000000e+00 2.69200000e+01 1.95000000e+00 1.80000000e+00
#  1.60000000e+01 6.00000000e-02 4.10000000e-01 2.83000000e+00
#  8.25000000e+00 1.29100000e+01 9.99000000e+02 3.60000000e+00
#  2.41000000e+00 2.12500000e+01 5.92000000e+00 2.12000000e+00
#  1.97100000e+01 4.50000000e+00 7.87000000e+00 3.00000000e-01
#  8.87000000e+00 1.43818773e+01 2.99000000e+00 6.73100000e+01
#  1.09000000e+00 1.58900000e+01 2.55300000e+01 1.10000000e-01
#  1.47800000e+01 7.08000000e+00 1.64400000e+01 2.91400000e+01
#  9.00000000e-01 1.13900000e+01 1.57800000e+01 9.38000000e+00
#  5.09000000e+00 1.79500000e+01 1.07900000e+01 4.93000000e+00
#  1.93000000e+00 3.96800000e+01 3.39400000e+01 3.11900000e+01
#  3.68000000e+00 1.24000000e+00 8.06000000e+00 1.06600000e+01
#  9.85000000e+00 1.32900000e+01 7.04000000e+00 2.80000000e-01
#  2.60000000e+00 5.51000000e+00 1.51200000e+01 1.37300000e+01
#  9.86000000e+00 5.19000000e+00 8.33000000e+00 2.14200000e+01
#  4.25800000e+01 5.00000000e-01 7.93000000e+00 3.90000000e+00
#  1.63000000e+00 1.72300000e+01 1.39000000e+00 1.04100000e+01
#  6.65000000e+00 4.96000000e+00 3.09600000e+01 4.60000000e+00
#  5.25000000e+00 6.34000000e+00 9.41000000e+00 3.48000000e+01
#  1.03300000e+01 1.12700000e+01 1.76000000e+01 2.26000000e+00
#  2.70600000e+01 5.43000000e+00 3.81000000e+00 1.23300000e+01
#  2.36000000e+01 6.45000000e+00 1.97600000e+01 1.00500000e+01
#  9.61000000e+00 7.00000000e-01 6.03000000e+00 3.52100000e+01
#  9.62000000e+00 1.57300000e+01 1.13500000e+01 1.91300000e+01
#  1.60000000e+00 1.68000000e+00 6.10000000e+00 1.24800000e+01
#  7.76000000e+00 3.58000000e+00 2.27600000e+01 7.69000000e+00
#  1.22800000e+01 3.00100000e+01 1.80000000e-01 1.74200000e+01
#  1.12600000e+01 3.49000000e+00 4.90000000e+00 1.30900000e+01
#  4.50000000e+02 2.02000000e+00 4.76400000e+01 3.29000000e+00
#  4.37000000e+01 1.11800000e+01 2.57800000e+01 1.99000000e+00]
#
# Número de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de rellenar: 0
# Todos los valores NaN en 'InGamePurchase' han sido rellenados con éxito.
#
# Conteo de valores por cada 'InGamePurchase' (incluyendo NaN después de rellenar):
# InGamePurchase
# 14.381877    12
# 0.020000      4
# 2.270000      3
# 2.670000      3
# 2.120000      3
#              ..
# 7.470000      1
# 2.470000      1
# 9.940000      1
# 5.330000      1
# 8.650000      1
# Name: count, Length: 484, dtype: int64

# %%
# Mostrar los valores distintos en la columna 'WinRate' ANTES de rellenar los NaN.
print("Valores distintos en 'WinRate' antes de rellenar NaN:")
print(df['WinRate'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'WinRate' ANTES de la imputación.
num_nan_win_rate_before = df['WinRate'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'WinRate' ANTES de rellenar: {num_nan_win_rate_before}")

# Calcular la media de 'WinRate'. La media es una opción común para variables numéricas continuas.
mean_win_rate = df['WinRate'].mean()
print(f"Media calculada para 'WinRate': {mean_win_rate:.3f}")

# Rellenar los valores NaN en la columna 'WinRate' con la media calculada.
# `df.loc[:, 'WinRate']` se usa para asegurar la modificación en el DataFrame original y evitar advertencias.
df.loc[:, 'WinRate'] = df['WinRate'].fillna(mean_win_rate)

# Mostrar los valores distintos en 'WinRate' DESPUÉS de rellenar los NaN para verificar la imputación.
print("\nValores distintos en 'WinRate' DESPUÉS de rellenar NaN:")
print(df['WinRate'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'WinRate' DESPUÉS de la imputación.
num_nan_win_rate_after = df['WinRate'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 
#  0.432      0.924      0.218      0.444      0.345      0.297
#  0.616      0.313      0.365      0.41       0.448      0.466
#  0.153      0.601      0.362      0.335      0.374      0.478
#  0.645      0.429      0.519      0.558      0.631      0.686
#  0.717      0.451      0.695      0.668      0.414      0.621
#  0.423      0.486      0.723      0.309      0.513      0.674
#  0.343      0.675      0.658      0.381      0.713      0.564
#  0.129      0.236      0.539     ]
#
# Número de valores NaN (faltantes) en la columna 'WinRate' DESPUÉS de rellenar: 0
# Todos los valores NaN en 'WinRate' han sido rellenados con éxito.
#
# Conteo de valores por cada 'WinRate' (incluyendo NaN después de rellenar):
# WinRate
# 0.512483    12
# 0.548000     4
# 0.508000     4
# 0.588000     4
# 0.680000     4
#             ..
# 0.796000     1
# 0.374000     1
# 0.335000     1
# 0.362000     1
# 0.601000     1
# Name: count, Length: 357, dtype: int64

# %%
# Mostrar los valores distintos en la columna 'InGamePurchase' ANTES de rellenar los NaN.
print("Valores distintos en 'InGamePurchase' antes de rellenar NaN:")
print(df['InGamePurchase'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'InGamePurchase' ANTES de la imputación.
num_nan_in_game_purchase_before = df['InGamePurchase'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'InGamePurchase' ANTES de rellenar: {num_nan_in_game_purchase_before}")

# Calcular la media de 'InGamePurchase'. La media es una opción común para variables numéricas continuas como esta.
mean_in_game_purchase = df['InGamePurchase'].mean()
print(f"Media calculada para 'InGamePurchase': {mean_in_game_purchase:.2f}")

# Rellenar los valores NaN en la columna 'InGamePurchase' con la media calculada.
# Se utiliza `df.loc[:, 'InGamePurchase']` para asegurar la modificación en el DataFrame original y evitar advertencias.
df.loc[:, 'InGamePurchase'] = df['InGamePurchase'].fillna(mean_in_game_purchase)

# Mostrar los valores distintos en 'InGamePurchase' DESPUÉS de rellenar los NaN para verificar la imputación.
print("\nValores distintos en 'InGamePurchase' DESPUÉS de rellenar NaN:")
print(df['InGamePurchase'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de la imputación.
num_nan_in_game_purchase_after = df['InGamePurchase'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de rellenar: {num_nan_in_game_purchase_after}")

# Confirmar si todos los valores NaN han sido rellenados.
if num_nan_in_game_purchase_after == 0:
    print("Todos los valores NaN en 'InGamePurchase' han sido rellenados con éxito.")

# Mostrar el conteo de valores por cada 'InGamePurchase', incluyendo NaN (si los hubiera, se espera 0 después de rellenar).
print("\nConteo de valores por cada 'InGamePurchase' (incluyendo NaN después de rellenar):")
print(df['InGamePurchase'].value_counts(dropna=False))
# Out:
# Valores distintos en 'InGamePurchase' antes de rellenar NaN:
# [7.38000000e+00 1.15600000e+01 4.20000000e-01 8.83000000e+00
#  2.38600000e+01 3.23000000e+00 3.12000000e+00 1.00000000e-02
#  4.28100000e+01 7.13000000e+00 2.48000000e+00 1.35100000e+01
#  5.15000000e+00 7.14000000e+00 8.00000000e+00 5.84000000e+00
#  4.17000000e+00 4.77000000e+00 6.40000000e-01 2.04000000e+00
#  1.16000000e+00 1.90000000e-01 3.89900000e+01 4.11500000e+01
#  5.69000000e+00 4.78000000e+00 6.66000000e+00 2.84200000e+01
#  3.35000000e+00 1.37400000e+01 5.48000000e+00 2.41900000e+01
#  5.90000000e+00 3.16400000e+01 7.05000000e+00 5.78000000e+00
#  1.06000000e+00 1.63900000e+01 1.43600000e+01 2.15000000e+00
#  8.52000000e+00 2.73000000e+00 1.91500000e+01 1.78800000e+01
#  4.08000000e+00 1.39000000e+01 6.36000000e+00 1.00000000e+00
#  4.92000000e+00 5.47000000e+00 2.23000000e+00 6.00000000e-01
#  1.08900000e+01 1.30400000e+01 1.44300000e+01 1.14000000e+00
#  1.74000000e+00 1.12200000e+01 1.87400000e+01 2.04400000e+01
#  2.61500000e+01 5.00000000e-02 2.96000000e+01 6.10000000e-01
#  2.49300000e+01 1.86400000e+01 8.82000000e+00 5.94000000e+00
#  6.79000000e+00 9.09000000e+00 1.74400000e+01 4.16000000e+00
#  9.49000000e+00 2.31400000e+01 5.18000000e+00 2.34900000e+01
#  4.33000000e+00 4.91000000e+00 2.16600000e+01 4.75000000e+00
#  8.45000000e+00 1.57100000e+01 3.92100000e+01 8.44000000e+00
#  4.02000000e+00 5.40000000e-01 1.73100000e+01 1.66000000e+00
#  3.68000000e+00 1.24000000e+00 8.06000000e+00 1.06600000e+01
#  9.85000000e+00 1.32900000e+01 7.04000000e+00 2.80000000e-01
#  2.60000000e+00 5.51000000e+00 1.51200000e+01 1.37300000e+01
#  9.86000000e+00 5.19000000e+00 8.33000000e+00 2.14200000e+01
#  4.25800000e+01 5.00000000e-01 7.93000000e+00 3.90000000e+00
#  1.63000000e+00 1.72300000e+01 1.39000000e+00 1.04100000e+01
#  6.65000000e+00 4.96000000e+00 3.09600000e+01 4.60000000e+00
#  5.25000000e+00 6.34000000e+00 9.41000000e+00 3.48000000e+01
#  1.03300000e+01 1.12700000e+01 1.76000000e+01 2.26000000e+00
#  2.70600000e+01 5.43000000e+00 3.81000000e+00 1.23300000e+01
#  2.36000000e+01 6.45000000e+00 1.97600000e+01 1.00500000e+01
#  9.61000000e+00 7.00000000e-01 6.03000000e+00 3.52100000e+01
#  9.62000000e+00 1.57300000e+01 1.13500000e+01 1.91300000e+01
#  1.60000000e+00 1.68000000e+00 6.10000000e+00 1.24800000e+01
#  7.76000000e+00 3.58000000e+00 2.27600000e+01 7.69000000e+00
#  1.22800000e+01 3.00100000e+01 1.80000000e-01 1.74200000e+01
#  1.12600000e+01 3.49000000e+00 4.90000000e+00 1.30900000e+01
#  4.50000000e+02 2.02000000e+00 4.76400000e+01 3.29000000e+00
#  4.37000000e+01 1.11800000e+01 2.57800000e+01 1.99000000e+00]
#
# Número de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de rellenar: 0
# Todos los valores NaN en 'InGamePurchase' han sido rellenados con éxito.
#
# Conteo de valores por cada 'InGamePurchase' (incluyendo NaN después de rellenar):
# InGamePurchase
# 14.381877    12
# 0.020000      4
# 2.270000      3
# 2.670000      3
# 2.120000      3
#              ..
# 7.470000      1
# 2.470000      1
# 9.940000      1
# 5.330000      1
# 8.650000      1
# Name: count, Length: 484, dtype: int64

# %%
# Mostrar los valores distintos en la columna 'FriendsInGame' ANTES de rellenar los NaN.
print("Valores distintos en 'FriendsInGame' antes de rellenar NaN:")
print(df['FriendsInGame'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'FriendsInGame' ANTES de la imputación.
num_nan_friends_in_game_before = df['FriendsInGame'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'FriendsInGame' ANTES de rellenar: {num_nan_friends_in_game_before}")

# Si hay valores NaN, proceder con la imputación.
if num_nan_friends_in_game_before > 0:
    # Calcular la media de 'FriendsInGame'. Dado que es un conteo, la media es una opción razonable.
    mean_friends_in_game = df['FriendsInGame'].mean()
    print(f"Media calculada para 'FriendsInGame': {mean_friends_in_game:.2f}")

    # Rellenar los valores NaN en la columna 'FriendsInGame' con la media calculada.
    # Se utiliza `df.loc[:, 'FriendsInGame']` para evitar advertencias y asegurar la modificación directa en `df`.
    df.loc[:, 'FriendsInGame'] = df['FriendsInGame'].fillna(mean_friends_in_game)

    # Mostrar los valores distintos en 'FriendsInGame' DESPUÉS de rellenar los NaN.
    print("\nValores distintos en 'FriendsInGame' DESPUÉS de rellenar NaN:")
    print(df['FriendsInGame'].unique())

    # Contar el número de valores NaN (faltantes) en la columna 'FriendsInGame' DESPUÉS de la imputación.
    num_nan_friends_in_game_after = df['FriendsInGame'].isnull().sum()
    print(f"\nNúmero de valores NaN (faltantes) en la columna 'FriendsInGame' DESPUÉS de rellenar: {num_nan_friends_in_game_after}")

    # Confirmar si todos los valores NaN han sido rellenados.
    if num_nan_friends_in_game_after == 0:
        print("Todos los valores NaN en 'FriendsInGame' han sido rellenados con éxito.")
# Si no hay NaN inicialmente, informar de ello.
else:
    print("No se encontraron valores NaN en la columna 'FriendsInGame'.")

# Mostrar el conteo de valores por cada 'FriendsInGame', incluyendo NaN (si los hubiera, se espera 0 después de rellenar).
print("\nConteo de valores por cada 'FriendsInGame' (incluyendo NaN después de rellenar si aplica):")
print(df['FriendsInGame'].value_counts(dropna=False))
# Out:
# Valores distintos en 'FriendsInGame' antes de rellenar NaN:
# [ 3.  8.  6. nan  0.  4.  1. 18. 10.  7.  5. 19.  9. 13. 14. 12. 16. 11.
#   2. 15. 20. 25. 17. 21.]
#
# Número de valores NaN (faltantes) en la columna 'FriendsInGame' ANTES de rellenar: 12
# Media calculada para 'FriendsInGame': 7.59
#
# Valores distintos en 'FriendsInGame' DESPUÉS de rellenar NaN:
# [ 3.          8.          6.          7.58921933  0.          4.
#   1.         18.         10.          7.          5.         19.
#   9.         13.         14.         12.         16.         11.
#   2.         15.         20.         25.         17.         21.        ]
#
# Número de valores NaN (faltantes) en la columna 'FriendsInGame' DESPUÉS de rellenar: 0
# Todos los valores NaN en 'FriendsInGame' han sido rellenados con éxito.
#
# Conteo de valores por cada 'FriendsInGame' (incluyendo NaN después de rellenar si aplica):
# FriendsInGame
# 7.000000     46
# 8.000000     45
# 6.000000     44
# 0.000000     43
# 9.000000     43
# 5.000000     41
# 10.000000    38
# 11.000000    30
# 3.000000     29
# 13.000000    29
# 2.000000     27
# 4.000000     24
# 12.000000    20
# 1.000000     19
# 14.000000    18
# 7.589219     12
# 15.000000    12
# 16.000000    11
# 18.000000     8
# 19.000000     4
# 17.000000     4
# 20.000000     1
# 25.000000     1
# 21.000000     1
# Name: count, dtype: int64

# %%
# Mostrar los valores distintos en la columna 'InGamePurchase' ANTES de rellenar los NaN.
print("Valores distintos en 'InGamePurchase' antes de rellenar NaN:")
print(df['InGamePurchase'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'InGamePurchase' ANTES de la imputación.
num_nan_in_game_purchase_before = df['InGamePurchase'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'InGamePurchase' ANTES de rellenar: {num_nan_in_game_purchase_before}")

# Calcular la media de 'InGamePurchase'. La media es una opción común para variables numéricas continuas como esta.
mean_in_game_purchase = df['InGamePurchase'].mean()
print(f"Media calculada para 'InGamePurchase': {mean_in_game_purchase:.2f}")

# Rellenar los valores NaN en la columna 'InGamePurchase' con la media calculada.
# Se utiliza `df.loc[:, 'InGamePurchase']` para asegurar la modificación en el DataFrame original y evitar advertencias.
df.loc[:, 'InGamePurchase'] = df['InGamePurchase'].fillna(mean_in_game_purchase)

# Mostrar los valores distintos en 'InGamePurchase' DESPUÉS de rellenar los NaN para verificar la imputación.
print("\nValores distintos en 'InGamePurchase' DESPUÉS de rellenar NaN:")
print(df['InGamePurchase'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de la imputación.
num_nan_in_game_purchase_after = df['InGamePurchase'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de rellenar: {num_nan_in_game_purchase_after}")

# Confirmar si todos los valores NaN han sido rellenados.
if num_nan_in_game_purchase_after == 0:
    print("Todos los valores NaN en 'InGamePurchase' han sido rellenados con éxito.")

# Mostrar el conteo de valores por cada 'InGamePurchase', incluyendo NaN (si los hubiera, se espera 0 después de rellenar).
print("\nConteo de valores por cada 'InGamePurchase' (incluyendo NaN después de rellenar):")
print(df['InGamePurchase'].value_counts(dropna=False))
# Out:
# Valores distintos en 'InGamePurchase' antes de rellenar NaN:
# [7.38000000e+00 1.15600000e+01 4.20000000e-01 8.83000000e+00
#  2.38600000e+01 3.23000000e+00 3.12000000e+00 1.00000000e-02
#  4.28100000e+01 7.13000000e+00 2.48000000e+00 1.35100000e+01
#  5.15000000e+00 7.14000000e+00 8.00000000e+00 5.84000000e+00
#  4.17000000e+00 4.77000000e+00 6.40000000e-01 2.04000000e+00
#  1.16000000e+00 1.90000000e-01 3.89900000e+01 4.11500000e+01
#  5.69000000e+00 4.78000000e+00 6.66000000e+00 2.84200000e+01
#  9.02000000e+00 1.18500000e+01 3.13000000e+00 2.41200000e+01
#  1.75800000e+01 2.29400000e+01 9.71000000e+00 1.32200000e+01
#  1.92800000e+01 1.71200000e+01 3.33000000e+00 1.05300000e+01
#  1.52100000e+01 1.04500000e+01 1.89800000e+01 2.14000000e+00
#  6.93000000e+00 2.69200000e+01 1.95000000e+00 1.80000000e+00
#  1.60000000e+01 6.00000000e-02 4.10000000e-01 2.83000000e+00
#  8.25000000e+00 1.29100000e+01 9.99000000e+02 3.60000000e+00
#  2.41000000e+00 2.12500000e+01 5.92000000e+00 2.12000000e+00
#  1.97100000e+01 4.50000000e+00 7.87000000e+00 3.00000000e-01
#  2.49300000e+01 1.86400000e+01 8.82000000e+00 5.94000000e+00
#  6.79000000e+00 9.09000000e+00 1.74400000e+01 4.16000000e+00
#  9.49000000e+00 2.31400000e+01 5.18000000e+00 2.34900000e+01
#  4.33000000e+00 4.91000000e+00 2.16600000e+01 4.75000000e+00
#  8.45000000e+00 1.57100000e+01 3.92100000e+01 8.44000000e+00
#  4.02000000e+00 5.40000000e-01 1.73100000e+01 1.66000000e+00
#  3.68000000e+00 1.24000000e+00 8.06000000e+00 1.06600000e+01
#  9.85000000e+00 1.32900000e+01 7.04000000e+00 2.80000000e-01
#  2.60000000e+00 5.51000000e+00 1.51200000e+01 1.37300000e+01
#  9.86000000e+00 5.19000000e+00 8.33000000e+00 2.14200000e+01
#  4.25800000e+01 5.00000000e-01 7.93000000e+00 3.90000000e+00
#  1.63000000e+00 1.72300000e+01 1.39000000e+00 1.04100000e+01
#  6.65000000e+00 4.96000000e+00 3.09600000e+01 4.60000000e+00
#  5.25000000e+00 6.34000000e+00 9.41000000e+00 3.48000000e+01
#  1.03300000e+01 1.12700000e+01 1.76000000e+01 2.26000000e+00
#  2.70600000e+01 5.43000000e+00 3.81000000e+00 1.23300000e+01
#  2.36000000e+01 6.45000000e+00 1.97600000e+01 1.00500000e+01
#  9.61000000e+00 7.00000000e-01 6.03000000e+00 3.52100000e+01
#  9.62000000e+00 1.57300000e+01 1.13500000e+01 1.91300000e+01
#  1.60000000e+00 1.68000000e+00 6.10000000e+00 1.24800000e+01
#  7.76000000e+00 3.58000000e+00 2.27600000e+01 7.69000000e+00
#  1.22800000e+01 3.00100000e+01 1.80000000e-01 1.74200000e+01
#  1.12600000e+01 3.49000000e+00 4.90000000e+00 1.30900000e+01
#  4.50000000e+02 2.02000000e+00 4.76400000e+01 3.29000000e+00
#  4.37000000e+01 1.11800000e+01 2.57800000e+01 1.99000000e+00]
#
# Número de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de rellenar: 0
# Todos los valores NaN en 'InGamePurchase' han sido rellenados con éxito.
#
# Conteo de valores por cada 'InGamePurchase' (incluyendo NaN después de rellenar):
# InGamePurchase
# 14.381877    12
# 0.020000      4
# 2.270000      3
# 2.670000      3
# 2.120000      3
#              ..
# 7.470000      1
# 2.470000      1
# 9.940000      1
# 5.330000      1
# 8.650000      1
# Name: count, Length: 484, dtype: int64

# %%
# Mostrar los valores distintos en la columna 'UsesVoiceChat'.
# Esta columna es binaria (0 o 1).
print("Valores distintos en 'UsesVoiceChat':")
print(df['UsesVoiceChat'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'UsesVoiceChat'.
num_nan_uses_voice_chat = df['UsesVoiceChat'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'UsesVoiceChat': {num_nan_uses_voice_chat}")

# Si hay valores NaN, se procede a rellenarlos de manera probabilística.
if num_nan_uses_voice_chat > 0:
    print("Estos valores 'nan' representan datos faltantes en la columna 'UsesVoiceChat'.")

    # Calcular la proporción de 0s y 1s en los datos existentes (no nulos).
    # `normalize=True` devuelve las frecuencias relativas.
    value_counts = df['UsesVoiceChat'].dropna().value_counts(normalize=True)
    prob_0 = value_counts.get(0, 0) # Probabilidad de 0 (no usa chat de voz)
    prob_1 = value_counts.get(1, 0) # Probabilidad de 1 (usa chat de voz)

    print(f"\nProporción de 0s (no usa chat de voz): {prob_0:.2f}")
    print(f"Proporción de 1s (usa chat de voz): {prob_1:.2f}")

    # Rellenar los valores NaN probabilísticamente, manteniendo la distribución original.
    # `np.random.choice` selecciona 0 o 1 basándose en las proporciones calculadas.
    import numpy as np
    fill_values = np.random.choice([0, 1], size=num_nan_uses_voice_chat, p=[prob_0, prob_1])

    # Obtener los índices de los valores NaN para asignar los valores rellenados.
    nan_indices = df[df['UsesVoiceChat'].isnull()].index

    # Asignar los valores rellenados a los NaN en el DataFrame.
    df.loc[nan_indices, 'UsesVoiceChat'] = fill_values

    print("\nValores distintos en 'UsesVoiceChat' DESPUÉS de rellenar NaN:")
    print(df['UsesVoiceChat'].unique())

    # Verificar nuevamente si quedan valores NaN después de la imputación.
    num_nan_uses_voice_chat_after = df['UsesVoiceChat'].isnull().sum()
    print(f"\nNúmero de valores NaN (faltantes) en la columna 'UsesVoiceChat' DESPUÉS de rellenar: {num_nan_uses_voice_chat_after}")

    # Confirmar si todos los valores NaN han sido rellenados.
    if num_nan_uses_voice_chat_after == 0:
        print("Todos los valores NaN en 'UsesVoiceChat' han sido rellenados con éxito.")
# Si no hay NaN inicialmente, informar de ello.
else:
    print("No se encontraron valores NaN en la columna 'UsesVoiceChat'.")

# Mostrar el conteo de valores por cada 'UsesVoiceChat', incluyendo NaN (se espera 0 después de rellenar).
print("\nConteo de valores por cada 'UsesVoiceChat' (incluyendo NaN después de rellenar si aplica):")
print(df['UsesVoiceChat'].value_counts(dropna=False))
# Out:
# Valores distintos en 'UsesVoiceChat':
# [1 0]
#
# Número de valores NaN (faltantes) en la columna 'UsesVoiceChat': 0
# No se encontraron valores NaN en la columna 'UsesVoiceChat'.
#
# Conteo de valores por cada 'UsesVoiceChat' (incluyendo NaN después de rellenar si aplica):
# UsesVoiceChat
# 1    300
# 0    250
# Name: count, dtype: int64

# %%
# Mostrar los valores distintos en la columna 'AchievementsUnlocked' ANTES de rellenar NaN.
print("Valores distintos en 'AchievementsUnlocked' antes de rellenar NaN:")
print(df['AchievementsUnlocked'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'AchievementsUnlocked' ANTES de la imputación.
num_nan_achievements_unlocked_before = df['AchievementsUnlocked'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'AchievementsUnlocked' ANTES de rellenar: {num_nan_achievements_unlocked_before}")

# Si hay valores NaN, proceder con la imputación.
if num_nan_achievements_unlocked_before > 0:
    # Calcular la media de 'AchievementsUnlocked'. Es una buena opción para variables de conteo si la distribución no es muy asimétrica.
    mean_achievements_unlocked = df['AchievementsUnlocked'].mean()
    print(f"Media calculada para 'AchievementsUnlocked': {mean_achievements_unlocked:.2f}")

    # Rellenar los valores NaN en la columna 'AchievementsUnlocked' con la media calculada.
    # Se utiliza `df.loc[:, 'AchievementsUnlocked']` para asegurar la modificación en el DataFrame original.
    df.loc[:, 'AchievementsUnlocked'] = df['AchievementsUnlocked'].fillna(mean_achievements_unlocked)

    # Mostrar los valores distintos en 'AchievementsUnlocked' DESPUÉS de rellenar NaN.
    print("\nValores distintos en 'AchievementsUnlocked' DESPUÉS de rellenar NaN:")
    print(df['AchievementsUnlocked'].unique())

    # Contar el número de valores NaN (faltantes) en la columna 'AchievementsUnlocked' DESPUÉS de la imputación.
    num_nan_achievements_unlocked_after = df['AchievementsUnlocked'].isnull().sum()
    print(f"\nNúmero de valores NaN (faltantes) en la columna 'AchievementsUnlocked' DESPUÉS de rellenar: {num_nan_achievements_unlocked_after}")

    # Confirmar si todos los valores NaN han sido rellenados.
    if num_nan_achievements_unlocked_after == 0:
        print("Todos los valores NaN en 'AchievementsUnlocked' han sido rellenados con éxito.")
# Si no hay NaN inicialmente, informar de ello.
else:
    print("No se encontraron valores NaN en la columna 'AchievementsUnlocked'.")

# Mostrar el conteo de valores por cada 'AchievementsUnlocked', incluyendo NaN (se espera 0 después de rellenar).
print("\nConteo de valores por cada 'AchievementsUnlocked' (incluyendo NaN después de rellenar si aplica):")
print(df['AchievementsUnlocked'].value_counts(dropna=False))
# Out:
# Valores distintos en 'AchievementsUnlocked' antes de rellenar NaN:
# [17 21 26 41 35 25 16  9 36 15 30 32 28 23 44  2 14 31 24 38 61  5 18 43
#   4 53  7 40 33 10 20 13  8  0 34  6 22 12 19 46  3 49 48 27 29 11 37 39
#  42 45  1 50 47]
#
# Número de valores NaN (faltantes) en la columna 'AchievementsUnlocked' ANTES de rellenar: 0
# No se encontraron valores NaN en la columna 'AchievementsUnlocked'.
#
# Conteo de valores por cada 'AchievementsUnlocked' (incluyendo NaN después de rellenar si aplica):
# AchievementsUnlocked
# 17    21
# 21    21
# 0     21
# 24    20
# 15    20
# 16    19
# 23    19
# 22    19
# 28    18
# 34    18
# 18    18
# 27    18
# 20    16
# 26    15
# 30    15
# 14    14
# 31    14
# 33    13
# 29    13
# 25    13
# 35    12
# 11    12
# 12    12
# 10    11
# 41    11
# 9     11
# 36    10
# 13    10
# 19     9
# 32     8
# 4      8
# 40     8
# 2      8
# 7      8
# 5      7
# 38     7
# 37     7
# 8      7
# 1      5
# 43     4
# 44     4
# 39     4
# 42     3
# 6      3
# 53     3
# 46     3
# 3      3
# 47     2
# 61     1
# 49     1
# 48     1
# 45     1
# 50     1
# Name: count, dtype: int64

# %%
# Mostrar los valores distintos en la columna 'InGamePurchase' ANTES de rellenar los NaN.
print("Valores distintos en 'InGamePurchase' antes de rellenar NaN:")
print(df['InGamePurchase'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'InGamePurchase' ANTES de la imputación.
num_nan_in_game_purchase_before = df['InGamePurchase'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'InGamePurchase' ANTES de rellenar: {num_nan_in_game_purchase_before}")

# Calcular la media de 'InGamePurchase'. La media es una opción común para variables numéricas continuas como esta.
mean_in_game_purchase = df['InGamePurchase'].mean()
print(f"Media calculada para 'InGamePurchase': {mean_in_game_purchase:.2f}")

# Rellenar los valores NaN en la columna 'InGamePurchase' con la media calculada.
# Se utiliza `df.loc[:, 'InGamePurchase']` para asegurar la modificación en el DataFrame original y evitar advertencias.
df.loc[:, 'InGamePurchase'] = df['InGamePurchase'].fillna(mean_in_game_purchase)

# Mostrar los valores distintos en 'InGamePurchase' DESPUÉS de rellenar los NaN para verificar la imputación.
print("\nValores distintos en 'InGamePurchase' DESPUÉS de rellenar NaN:")
print(df['InGamePurchase'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de la imputación.
num_nan_in_game_purchase_after = df['InGamePurchase'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de rellenar: {num_nan_in_game_purchase_after}")

# Confirmar si todos los valores NaN han sido rellenados.
if num_nan_in_game_purchase_after == 0:
    print("Todos los valores NaN en 'InGamePurchase' han sido rellenados con éxito.")

# Mostrar el conteo de valores por cada 'InGamePurchase', incluyendo NaN (si los hubiera, se espera 0 después de rellenar).
print("\nConteo de valores por cada 'InGamePurchase' (incluyendo NaN después de rellenar):")
print(df['InGamePurchase'].value_counts(dropna=False))
# Out:
# Valores distintos en 'InGamePurchase' antes de rellenar NaN:
# [7.38000000e+00 1.15600000e+01 4.20000000e-01 8.83000000e+00
#  2.38600000e+01 3.23000000e+00 3.12000000e+00 1.00000000e-02
#  4.28100000e+01 7.13000000e+00 2.48000000e+00 1.35100000e+01
#  5.15000000e+00 7.14000000e+00 8.00000000e+00 5.84000000e+00
#  4.17000000e+00 4.77000000e+00 6.40000000e-01 2.04000000e+00
#  1.16000000e+00 1.90000000e-01 3.89900000e+01 4.11500000e+01
#  5.69000000e+00 4.78000000e+00 6.66000000e+00 2.84200000e+01
#  9.02000000e+00 1.18500000e+01 3.13000000e+00 2.41200000e+01
#  1.75800000e+01 2.29400000e+01 9.71000000e+00 1.32200000e+01
#  1.92800000e+01 1.71200000e+01 3.33000000e+00 1.05300000e+01
#  1.52100000e+01 1.04500000e+01 1.89800000e+01 2.14000000e+00
#  6.93000000e+00 2.69200000e+01 1.95000000e+00 1.80000000e+00
#  1.60000000e+01 6.00000000e-02 4.10000000e-01 2.83000000e+00
#  8.25000000e+00 1.29100000e+01 9.99000000e+02 3.60000000e+00
#  2.41000000e+00 2.12500000e+01 5.92000000e+00 2.12000000e+00
#  1.97100000e+01 4.50000000e+00 7.87000000e+00 3.00000000e-01
#  8.87000000e+00 1.43818773e+01 2.99000000e+00 6.73100000e+01
#  1.09000000e+00 1.58900000e+01 2.55300000e+01 1.10000000e-01
#  1.47800000e+01 7.08000000e+00 1.64400000e+01 2.91400000e+01
#  9.00000000e-01 1.13900000e+01 1.57800000e+01 9.38000000e+00
#  5.09000000e+00 1.79500000e+01 1.07900000e+01 4.93000000e+00
#  1.93000000e+00 3.96800000e+01 3.39400000e+01 3.11900000e+01
#  9.54000000e+00 7.83000000e+00 5.74000000e+00 1.51100000e+01
#  2.03000000e+01 2.76300000e+01 1.60200000e+01 1.76000000e+00
#  8.78000000e+00 3.91400000e+01 2.21400000e+01 8.55000000e+00
#  1.87300000e+01 1.11900000e+01 1.34000000e+00 6.75000000e+00
#  2.61200000e+01 1.50000000e-01 5.98000000e+00 8.30000000e-01
#  4.23800000e+01 1.14500000e+01 1.15000000e+01 2.37100000e+01
#  4.02700000e+01 7.43000000e+00 1.71800000e+01 2.00000000e-02
#  6.65000000e+00 4.96000000e+00 3.09600000e+01 4.60000000e+00
#  5.25000000e+00 6.34000000e+00 9.41000000e+00 3.48000000e+01
#  1.03300000e+01 1.12700000e+01 1.76000000e+01 2.26000000e+00
#  2.70600000e+01 5.43000000e+00 3.81000000e+00 1.23300000e+01
#  2.36000000e+01 6.45000000e+00 1.97600000e+01 1.00500000e+01
#  9.61000000e+00 7.00000000e-01 6.03000000e+00 3.52100000e+01
#  9.62000000e+00 1.57300000e+01 1.13500000e+01 1.91300000e+01
#  1.60000000e+00 1.68000000e+00 6.10000000e+00 1.24800000e+01
#  7.76000000e+00 3.58000000e+00 2.27600000e+01 7.69000000e+00
#  1.22800000e+01 3.00100000e+01 1.80000000e-01 1.74200000e+01
#  1.12600000e+01 3.49000000e+00 4.90000000e+00 1.30900000e+01
#  4.50000000e+02 2.02000000e+00 4.76400000e+01 3.29000000e+00
#  4.37000000e+01 1.11800000e+01 2.57800000e+01 1.99000000e+00]
#
# Número de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de rellenar: 0
# Todos los valores NaN en 'InGamePurchase' han sido rellenados con éxito.
#
# Conteo de valores por cada 'InGamePurchase' (incluyendo NaN después de rellenar):
# InGamePurchase
# 14.381877    12
# 0.020000      4
# 2.270000      3
# 2.670000      3
# 2.120000      3
#              ..
# 7.470000      1
# 2.470000      1
# 9.940000      1
# 5.330000      1
# 8.650000      1
# Name: count, Length: 484, dtype: int64

# %%
# Mostrar los valores distintos en la columna 'ReportsReceivedLast30D' ANTES de rellenar NaN.
print("Valores distintos en 'ReportsReceivedLast30D' antes de rellenar NaN:")
print(df['ReportsReceivedLast30D'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'ReportsReceivedLast30D' ANTES de la imputación.
num_nan_reports_received_before = df['ReportsReceivedLast30D'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'ReportsReceivedLast30D' ANTES de rellenar: {num_nan_reports_received_before}")

# Si hay valores NaN, proceder con la imputación.
if num_nan_reports_received_before > 0:
    # Calcular la media de 'ReportsReceivedLast30D'. Una opción común para imputar valores faltantes en variables numéricas.
    mean_reports_received = df['ReportsReceivedLast30D'].mean()
    print(f"Media calculada para 'ReportsReceivedLast30D': {mean_reports_received:.2f}")

    # Rellenar los valores NaN en la columna 'ReportsReceivedLast30D' con la media calculada.
    # Se utiliza `df.loc[:, 'ReportsReceivedLast30D']` para asegurar la modificación en el DataFrame original.
    df.loc[:, 'ReportsReceivedLast30D'] = df['ReportsReceivedLast30D'].fillna(mean_reports_received)

    # Mostrar los valores distintos en 'ReportsReceivedLast30D' DESPUÉS de rellenar NaN.
    print("\nValores distintos en 'ReportsReceivedLast30D' DESPUÉS de rellenar NaN:")
    print(df['ReportsReceivedLast30D'].unique())

    # Contar el número de valores NaN (faltantes) en la columna 'ReportsReceivedLast30D' DESPUÉS de la imputación.
    num_nan_reports_received_after = df['ReportsReceivedLast30D'].isnull().sum()
    print(f"\nNúmero de valores NaN (faltantes) en la columna 'ReportsReceivedLast30D' DESPUÉS de rellenar: {num_nan_reports_received_after}")

    # Confirmar si todos los valores NaN han sido rellenados.
    if num_nan_reports_received_after == 0:
        print("Todos los valores NaN en 'ReportsReceivedLast30D' han sido rellenados con éxito.")
# Si no hay NaN inicialmente, informar de ello.
else:
    print("No se encontraron valores NaN en la columna 'ReportsReceivedLast30D'.")

# Mostrar el conteo de valores por cada 'ReportsReceivedLast30D', incluyendo NaN (se espera 0 después de rellenar).
print("\nConteo de valores por cada 'ReportsReceivedLast30D' (incluyendo NaN después de rellenar si aplica):")
print(df['ReportsReceivedLast30D'].value_counts(dropna=False))
# Out:
# Valores distintos en 'ReportsReceivedLast30D' antes de rellenar NaN:
# [0 2 1 5 3 4]
#
# Número de valores NaN (faltantes) en la columna 'ReportsReceivedLast30D' ANTES de rellenar: 0
# No se encontraron valores NaN en la columna 'ReportsReceivedLast30D'.
#
# Conteo de valores por cada 'ReportsReceivedLast30D' (incluyendo NaN después de rellenar si aplica):
# ReportsReceivedLast30D
# 1    200
# 0    192
# 2    107
# 3     31
# 4     15
# 5      5
# Name: count, dtype: int64

# %%
# Mostrar los valores distintos en la columna 'Churn30D'.
# Esta columna es binaria, indicando si un jugador se fue en los últimos 30 días (1) o no (0).
print("Valores distintos en 'Churn30D':")
print(df['Churn30D'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'Churn30D'.
num_nan_churn30d = df['Churn30D'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'Churn30D': {num_nan_churn30d}")

# Si hay valores NaN, proceder a rellenarlos de manera probabilística.
if num_nan_churn30d > 0:
    print("Estos valores 'nan' representan datos faltantes en la columna 'Churn30D'.")

    # Calcular la proporción de 0s y 1s en los datos existentes (no nulos).
    # `normalize=True` devuelve las frecuencias relativas, lo cual es clave para mantener la distribución.
    value_counts = df['Churn30D'].dropna().value_counts(normalize=True)
    prob_0 = value_counts.get(0, 0) # Probabilidad de no abandono (0)
    prob_1 = value_counts.get(1, 0) # Probabilidad de abandono (1)

    print(f"\nProporción de 0s (no churn): {prob_0:.2f}")
    print(f"Proporción de 1s (churn): {prob_1:.2f}")

    # Rellenar los valores NaN probabilísticamente, para preservar la distribución original de la variable objetivo.
    # `np.random.choice` es útil aquí para muestrear valores (0 o 1) basándose en las probabilidades.
    import numpy as np
    fill_values = np.random.choice([0, 1], size=num_nan_churn30d, p=[prob_0, prob_1])

    # Obtener los índices de los valores NaN.
    nan_indices = df[df['Churn30D'].isnull()].index

    # Asignar los valores rellenados a los NaN en el DataFrame.
    df.loc[nan_indices, 'Churn30D'] = fill_values

    print("\nValores distintos en 'Churn30D' DESPUÉS de rellenar NaN:")
    print(df['Churn30D'].unique())

    # Verificar nuevamente si quedan valores NaN.
    num_nan_churn30d_after = df['Churn30D'].isnull().sum()
    print(f"\nNúmero de valores NaN (faltantes) en la columna 'Churn30D' DESPUÉS de rellenar: {num_nan_churn30d_after}")

    # Confirmar si todos los valores NaN han sido rellenados con éxito.
    if num_nan_churn30d_after == 0:
        print("Todos los valores NaN en 'Churn30D' han sido rellenados con éxito.")
# Si no hay NaN inicialmente, informar de ello.
else:
    print("No se encontraron valores NaN en la columna 'Churn30D'.")

# Mostrar el conteo de valores por cada 'Churn30D', incluyendo NaN (se espera 0 después de rellenar).
# Esto es importante para entender el balance de clases en la variable objetivo.
print("\nConteo de valores por cada 'Churn30D' (incluyendo NaN después de rellenar si aplica):")
print(df['Churn30D'].value_counts(dropna=False))
# Out:
# Valores distintos en 'Churn30D':
# [0 1]
#
# Número de valores NaN (faltantes) en la columna 'Churn30D': 0
# No se encontraron valores NaN en la columna 'Churn30D'.
#
# Conteo de valores por cada 'Churn30D' (incluyendo NaN después de rellenar si aplica):
# Churn30D
# 0    324
# 1    226
# Name: count, dtype: int64

# %%
# Mostrar los valores distintos en la columna 'InGamePurchase' ANTES de rellenar los NaN.
print("Valores distintos en 'InGamePurchase' antes de rellenar NaN:")
print(df['InGamePurchase'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'InGamePurchase' ANTES de la imputación.
num_nan_in_game_purchase_before = df['InGamePurchase'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'InGamePurchase' ANTES de rellenar: {num_nan_in_game_purchase_before}")

# Calcular la media de 'InGamePurchase'. La media es una opción común para variables numéricas continuas como esta.
mean_in_game_purchase = df['InGamePurchase'].mean()
print(f"Media calculada para 'InGamePurchase': {mean_in_game_purchase:.2f}")

# Rellenar los valores NaN en la columna 'InGamePurchase' con la media calculada.
# Se utiliza `df.loc[:, 'InGamePurchase']` para asegurar la modificación en el DataFrame original y evitar advertencias.
df.loc[:, 'InGamePurchase'] = df['InGamePurchase'].fillna(mean_in_game_purchase)

# Mostrar los valores distintos en 'InGamePurchase' DESPUÉS de rellenar los NaN para verificar la imputación.
print("\nValores distintos en 'InGamePurchase' DESPUÉS de rellenar NaN:")
print(df['InGamePurchase'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de la imputación.
num_nan_in_game_purchase_after = df['InGamePurchase'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de rellenar: {num_nan_in_game_purchase_after}")

# Confirmar si todos los valores NaN han sido rellenados.
if num_nan_in_game_purchase_after == 0:
    print("Todos los valores NaN en 'InGamePurchase' han sido rellenados con éxito.")

# Mostrar el conteo de valores por cada 'InGamePurchase', incluyendo NaN (si los hubiera, se espera 0 después de rellenar).
print("\nConteo de valores por cada 'InGamePurchase' (incluyendo NaN después de rellenar):")
print(df['InGamePurchase'].value_counts(dropna=False))
# Out:
# Valores distintos en 'InGamePurchase' antes de rellenar NaN:
# [7.38000000e+00 1.15600000e+01 4.20000000e-01 8.83000000e+00
#  2.38600000e+01 3.23000000e+00 3.12000000e+00 1.00000000e-02
#  4.28100000e+01 7.13000000e+00 2.48000000e+00 1.35100000e+01
#  5.15000000e+00 7.14000000e+00 8.00000000e+00 5.84000000e+00
#  4.17000000e+00 4.77000000e+00 6.40000000e-01 2.04000000e+00
#  1.16000000e+00 1.90000000e-01 3.89900000e+01 4.11500000e+01
#  5.69000000e+00 4.78000000e+00 6.66000000e+00 2.84200000e+01
#  9.02000000e+00 1.18500000e+01 3.13000000e+00 2.41200000e+01
#  1.75800000e+01 2.29400000e+01 9.71000000e+00 1.32200000e+01
#  1.92800000e+01 1.71200000e+01 3.33000000e+00 1.05300000e+01
#  1.52100000e+01 1.04500000e+01 1.89800000e+01 2.14000000e+00
#  6.93000000e+00 2.69200000e+01 1.95000000e+00 1.80000000e+00
#  4.92000000e+00 5.47000000e+00 2.23000000e+00 6.00000000e-01
#  1.08900000e+01 1.30400000e+01 1.44300000e+01 1.14000000e+00
#  1.74000000e+00 1.12200000e+01 1.87400000e+01 2.04400000e+01
#  2.61500000e+01 5.00000000e-02 2.96000000e+01 6.10000000e-01
#  2.49300000e+01 1.86400000e+01 8.82000000e+00 5.94000000e+00
#  6.79000000e+00 9.09000000e+00 1.74400000e+01 4.16000000e+00
#  9.49000000e+00 2.31400000e+01 5.18000000e+00 2.34900000e+01
#  4.33000000e+00 4.91000000e+00 2.16600000e+01 4.75000000e+00
#  8.45000000e+00 1.57100000e+01 3.92100000e+01 8.44000000e+00
#  4.02000000e+00 5.40000000e-01 1.73100000e+01 1.66000000e+00
#  3.68000000e+00 1.24000000e+00 8.06000000e+00 1.06600000e+01
#  9.85000000e+00 1.32900000e+01 7.04000000e+00 2.80000000e-01
#  2.60000000e+00 5.51000000e+00 1.51200000e+01 1.37300000e+01
#  9.86000000e+00 5.19000000e+00 8.33000000e+00 2.14200000e+01
#  4.25800000e+01 5.00000000e-01 7.93000000e+00 3.90000000e+00
#  1.63000000e+00 1.72300000e+01 1.39000000e+00 1.04100000e+01
#  6.65000000e+00 4.96000000e+00 3.09600000e+01 4.60000000e+00
#  5.25000000e+00 6.34000000e+00 9.41000000e+00 3.48000000e+01
#  1.03300000e+01 1.12700000e+01 1.76000000e+01 2.26000000e+00
#  2.70600000e+01 5.43000000e+00 3.81000000e+00 1.23300000e+01
#  2.36000000e+01 6.45000000e+00 1.97600000e+01 1.00500000e+01
#  9.61000000e+00 7.00000000e-01 6.03000000e+00 3.52100000e+01
#  9.62000000e+00 1.57300000e+01 1.13500000e+01 1.91300000e+01
#  1.60000000e+00 1.68000000e+00 6.10000000e+00 1.24800000e+01
#  7.76000000e+00 3.58000000e+00 2.27600000e+01 7.69000000e+00
#  1.22800000e+01 3.00100000e+01 1.80000000e-01 1.74200000e+01
#  1.12600000e+01 3.49000000e+00 4.90000000e+00 1.30900000e+01
#  4.50000000e+02 2.02000000e+00 4.76400000e+01 3.29000000e+00
#  4.37000000e+01 1.11800000e+01 2.57800000e+01 1.99000000e+00]
#
# Número de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de rellenar: 0
# Todos los valores NaN en 'InGamePurchase' han sido rellenados con éxito.
#
# Conteo de valores por cada 'InGamePurchase' (incluyendo NaN después de rellenar):
# InGamePurchase
# 14.381877    12
# 0.020000      4
# 2.270000      3
# 2.670000      3
# 2.120000      3
#              ..
# 7.470000      1
# 2.470000      1
# 9.940000      1
# 5.330000      1
# 8.650000      1
# Name: count, Length: 484, dtype: int64

# %%
# Mostrar los valores distintos en la columna 'InGamePurchase' ANTES de rellenar los NaN.
print("Valores distintos en 'InGamePurchase' antes de rellenar NaN:")
print(df['InGamePurchase'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'InGamePurchase' ANTES de la imputación.
num_nan_in_game_purchase_before = df['InGamePurchase'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'InGamePurchase' ANTES de rellenar: {num_nan_in_game_purchase_before}")

# Calcular la media de 'InGamePurchase'. La media es una opción común para variables numéricas continuas como esta.
mean_in_game_purchase = df['InGamePurchase'].mean()
print(f"Media calculada para 'InGamePurchase': {mean_in_game_purchase:.2f}")

# Rellenar los valores NaN en la columna 'InGamePurchase' con la media calculada.
# Se utiliza `df.loc[:, 'InGamePurchase']` para asegurar la modificación en el DataFrame original y evitar advertencias.
df.loc[:, 'InGamePurchase'] = df['InGamePurchase'].fillna(mean_in_game_purchase)

# Mostrar los valores distintos en 'InGamePurchase' DESPUÉS de rellenar los NaN para verificar la imputación.
print("\nValores distintos en 'InGamePurchase' DESPUÉS de rellenar NaN:")
print(df['InGamePurchase'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de la imputación.
num_nan_in_game_purchase_after = df['InGamePurchase'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de rellenar: {num_nan_in_game_purchase_after}")

# Confirmar si todos los valores NaN han sido rellenados.
if num_nan_in_game_purchase_after == 0:
    print("Todos los valores NaN en 'InGamePurchase' han sido rellenados con éxito.")

# Mostrar el conteo de valores por cada 'InGamePurchase', incluyendo NaN (si los hubiera, se espera 0 después de rellenar).
print("\nConteo de valores por cada 'InGamePurchase' (incluyendo NaN después de rellenar):")
print(df['InGamePurchase'].value_counts(dropna=False))
# Out:
# Valores distintos en 'InGamePurchase' antes de rellenar NaN:
# [7.38000000e+00 1.15600000e+01 4.20000000e-01 8.83000000e+00
#  2.38600000e+01 3.23000000e+00 3.12000000e+00 1.00000000e-02
#  4.28100000e+01 7.13000000e+00 2.48000000e+00 1.35100000e+01
#  5.15000000e+00 7.14000000e+00 8.00000000e+00 5.84000000e+00
#  4.17000000e+00 4.77000000e+00 6.40000000e-01 2.04000000e+00
#  1.16000000e+00 1.90000000e-01 3.89900000e+01 4.11500000e+01
#  5.69000000e+00 4.78000000e+00 6.66000000e+00 2.84200000e+01
#  9.02000000e+00 1.18500000e+01 3.13000000e+00 2.41200000e+01
#  1.75800000e+01 2.29400000e+01 9.71000000e+00 1.32200000e+01
#  1.92800000e+01 1.71200000e+01 3.33000000e+00 1.05300000e+01
#  1.52100000e+01 1.04500000e+01 1.89800000e+01 2.14000000e+00
#  6.93000000e+00 2.69200000e+01 1.95000000e+00 1.80000000e+00
#  1.60000000e+01 6.00000000e-02 4.10000000e-01 2.83000000e+00
#  8.25000000e+00 1.29100000e+01 9.99000000e+02 3.60000000e+00
#  2.41000000e+00 2.12500000e+01 5.92000000e+00 2.12000000e+00
#  1.97100000e+01 4.50000000e+00 7.87000000e+00 3.00000000e-01
#  8.87000000e+00 1.43818773e+01 2.99000000e+00 6.73100000e+01
#  1.09000000e+00 1.58900000e+01 2.55300000e+01 1.10000000e-01
#  1.47800000e+01 7.08000000e+00 1.64400000e+01 2.91400000e+01
#  9.00000000e-01 1.13900000e+01 1.57800000e+01 9.38000000e+00
#  5.09000000e+00 1.79500000e+01 1.07900000e+01 4.93000000e+00
#  1.93000000e+00 3.96800000e+01 3.39400000e+01 3.11900000e+01
#  9.54000000e+00 7.83000000e+00 5.74000000e+00 1.51100000e+01
#  2.03000000e+01 2.76300000e+01 1.60200000e+01 1.76000000e+00
#  9.85000000e+00 1.32900000e+01 7.04000000e+00 2.80000000e-01
#  2.60000000e+00 5.51000000e+00 1.51200000e+01 1.37300000e+01
#  9.86000000e+00 5.19000000e+00 8.33000000e+00 2.14200000e+01
#  4.25800000e+01 5.00000000e-01 7.93000000e+00 3.90000000e+00
#  1.63000000e+00 1.72300000e+01 1.39000000e+00 1.04100000e+01
#  6.65000000e+00 4.96000000e+00 3.09600000e+01 4.60000000e+00
#  5.25000000e+00 6.34000000e+00 9.41000000e+00 3.48000000e+01
#  1.03300000e+01 1.12700000e+01 1.76000000e+01 2.26000000e+00
#  2.70600000e+01 5.43000000e+00 3.81000000e+00 1.23300000e+01
#  2.36000000e+01 6.45000000e+00 1.97600000e+01 1.00500000e+01
#  9.61000000e+00 7.00000000e-01 6.03000000e+00 3.52100000e+01
#  9.62000000e+00 1.57300000e+01 1.13500000e+01 1.91300000e+01
#  1.60000000e+00 1.68000000e+00 6.10000000e+00 1.24800000e+01
#  7.76000000e+00 3.58000000e+00 2.27600000e+01 7.69000000e+00
#  1.22800000e+01 3.00100000e+01 1.80000000e-01 1.74200000e+01
#  1.12600000e+01 3.49000000e+00 4.90000000e+00 1.30900000e+01
#  4.50000000e+02 2.02000000e+00 4.76400000e+01 3.29000000e+00
#  4.37000000e+01 1.11800000e+01 2.57800000e+01 1.99000000e+00]
#
# Número de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de rellenar: 0
# Todos los valores NaN en 'InGamePurchase' han sido rellenados con éxito.
#
# Conteo de valores por cada 'InGamePurchase' (incluyendo NaN después de rellenar):
# InGamePurchase
# 14.381877    12
# 0.020000      4
# 2.270000      3
# 2.670000      3
# 2.120000      3
#              ..
# 7.470000      1
# 2.470000      1
# 9.940000      1
# 5.330000      1
# 8.650000      1
# Name: count, Length: 484, dtype: int64

# %%
# Mostrar los valores distintos en la columna 'InGamePurchase' ANTES de rellenar los NaN.
print("Valores distintos en 'InGamePurchase' antes de rellenar NaN:")
print(df['InGamePurchase'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'InGamePurchase' ANTES de la imputación.
num_nan_in_game_purchase_before = df['InGamePurchase'].isnull().sum()
print(f"\nNúmero de valores NaN (faltantes) en la columna 'InGamePurchase' ANTES de rellenar: {num_nan_in_game_purchase_before}")

# Calcular la media de 'InGamePurchase'. La media es una opción común para variables numéricas continuas como esta.
mean_in_game_purchase = df['InGamePurchase'].mean()
print(f"Media calculada para 'InGamePurchase': {mean_in_game_purchase:.2f}")

# Rellenar los valores NaN en la columna 'InGamePurchase' con la media calculada.
# Se utiliza `df.loc[:, 'InGamePurchase']` para asegurar la modificación en el DataFrame original y evitar advertencias.
df.loc[:, 'InGamePurchase'] = df['InGamePurchase'].fillna(mean_in_game_purchase)

# Mostrar los valores distintos en 'InGamePurchase' DESPUÉS de rellenar los NaN para verificar la imputación.
print("\nValores distintos en 'InGamePurchase' DESPUÉS de rellenar NaN:")
print(df['InGamePurchase'].unique())

# Contar el número de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de la imputación.
num_nan_in_game_purchase_after = df['InGamePurchase'].isnull().sum()
#  8.45000000e+00 1.57100000e+01 3.92100000e+01 8.44000000e+00
#  4.02000000e+00 5.40000000e-01 1.73100000e+01 1.66000000e+00
#  3.68000000e+00 1.24000000e+00 8.06000000e+00 1.06600000e+01
#  9.85000000e+00 1.32900000e+01 7.04000000e+00 2.80000000e-01
#  2.60000000e+00 5.51000000e+00 1.51200000e+01 1.37300000e+01
#  9.86000000e+00 5.19000000e+00 8.33000000e+00 2.14200000e+01
#  4.25800000e+01 5.00000000e-01 7.93000000e+00 3.90000000e+00
#  1.63000000e+00 1.72300000e+01 1.39000000e+00 1.04100000e+01
#  6.65000000e+00 4.96000000e+00 3.09600000e+01 4.60000000e+00
#  5.25000000e+00 6.34000000e+00 9.41000000e+00 3.48000000e+01
#  1.03300000e+01 1.12700000e+01 1.76000000e+01 2.26000000e+00
#  2.70600000e+01 5.43000000e+00 3.81000000e+00 1.23300000e+01
#  2.36000000e+01 6.45000000e+00 1.97600000e+01 1.00500000e+01
#  9.61000000e+00 7.00000000e-01 6.03000000e+00 3.52100000e+01
#  9.62000000e+00 1.57300000e+01 1.13500000e+01 1.91300000e+01
#  1.60000000e+00 1.68000000e+00 6.10000000e+00 1.24800000e+01
#  7.76000000e+00 3.58000000e+00 2.27600000e+01 7.69000000e+00
#  1.22800000e+01 3.00100000e+01 1.80000000e-01 1.74200000e+01
#  1.12600000e+01 3.49000000e+00 4.90000000e+00 1.30900000e+01
#  4.50000000e+02 2.02000000e+00 4.76400000e+01 3.29000000e+00
#  4.37000000e+01 1.11800000e+01 2.57800000e+01 1.99000000e+00]
#
# Número de valores NaN (faltantes) en la columna 'InGamePurchase' DESPUÉS de rellenar: 0
# Todos los valores NaN en 'InGamePurchase' han sido rellenados con éxito.
#
# Conteo de valores por cada 'InGamePurchase' (incluyendo NaN después de rellenar):
# InGamePurchase
# 14.381877    12
# 0.020000      4
# 2.270000      3
# 2.670000      3
# 2.120000      3
#              ..
# 7.470000      1
# 2.470000      1
# 9.940000      1
# 5.330000      1
# 8.650000      1
# Name: count, Length: 484, dtype: int64

# %%
print(df.to_string())
# Out:
#     PlayerID   Age Region Platform PreferredGenre  SessionsPerWeek  AvgSessionMinutes  DaysSinceLastLogin  PlayerLevel  MatchesPlayedLast30D   WinRate  InGamePurchase  FriendsInGame  UsesVoiceChat  AchievementsUnlocked  ReportsReceivedLast30D  Churn30D
# 0      P0001  22.0  LATAM       PC            RPG                3               87.0                  11           59                    14  0.481000        7.380000       3.000000              1                    17                       0         0
# 1      P0002  21.0     EU       PC        Shooter                7              113.0                   0           45                    24  0.475000       11.560000       8.000000              1                    21                       2         0
# 2      P0003  40.0  LATAM   Mobile        Shooter                3               67.0                   3           68                    27  0.341000        0.420000       6.000000              1                    26                       1         0
# 3      P0004  37.0    USA       PC        Shooter                0               48.0                   9           40                    39  0.225000        8.830000       7.589219              1                    41                       2         0
# 4      P0005  28.0     EU  Console        Shooter                3               90.0                  15           51                    15  0.454000       23.860000       0.000000              0                    35                       1         1
# 5      P0006  23.0    USA   Mobile       Strategy                5               32.0                  10           33                    35  0.610000        3.230000       4.000000              0                    25                       0         1
# 6      P0007  32.0    USA       PC  Battle Royale                5               25.0                   6           41                    50  0.422000        3.120000       6.000000              0                    16                       5         1
# 7      P0008  26.0     EU   Mobile           MOBA                3               66.0                  13           30                    40  0.303000        0.010000       1.000000              0                     9                       1         1
# 8      P0009  25.0  LATAM       PC           MOBA                5               70.0                   9            1                    13  0.711000       42.810000       0.000000              0                    21                       0         1
# 9      P0010  17.0     EU   Mobile        Shooter                4               72.0                  16            9                    33  0.796000        7.130000      18.000000              0                    36                       1         0
# 10     P0011  20.0     EU       PC            RPG                7              109.0                   1           36                    20  0.638000        2.480000       8.000000              1                    15                       0         0
# 11     P0012  34.0  LATAM   Mobile       Strategy                3               76.0                   6           46                    46  0.510000       13.510000       3.000000              1                    30                       1         1
# 12     P0013  31.0    USA       PC         Sports                7              138.0                   5           31                     6  0.679000        5.150000      10.000000              1                    25                       2         0
# 13     P0014  21.0     EU       PC       Strategy                6              119.0                  11           32                    25  0.210000        7.140000       7.000000              0                    17                       1         1
# 14     P0015  16.0  LATAM   Mobile  Battle Royale                6              151.0                   0           47                    32  0.509000        8.000000       7.000000              0                    32                       3         0
# 15     P0016  19.0     EU       PC       Strategy                5               71.0                   7           48                    21  0.617000        5.840000       5.000000              0                    32                       3         0
# 16     P0017  30.0     EU       PC        Shooter                7               76.0                  14           54                    13  0.707000        4.170000      10.000000              1                    28                       2         1
# 17     P0018  16.0   APAC   Mobile         Sports                4               57.0                   8           27                    56  0.399000        4.770000       8.000000              0                    23                       0         0
# 18     P0019  26.0     EU  Console            RPG                5               48.0                   2           47                    17  0.532000        0.640000      19.000000              1                    44                       3         1
# 19     P0020  34.0     EU       PC       Strategy                3               72.0                  11           50                     9  0.450000        2.040000       9.000000              1                     2                       1         0
# 20     P0021  22.0     EU       PC       Strategy                3              123.0                   0           39                    22  0.378000        1.160000       6.000000              1                    14                       0         1
# 21     P0022  31.0     EU  Console  Battle Royale                3              102.0                  22           26                    23  0.579000        0.190000       8.000000              1                    31                       5         0
# 22     P0023  27.0  LATAM       PC         Sports                8               44.0                  22            1                    25  0.588000       38.990000       5.000000              0                    24                       1         0
# 23     P0024  24.0     EU       PC       Strategy                8              420.0                  11           31                    26  0.424000       41.150000       0.000000              1                    38                       2         0
# 24     P0025  39.0    USA  Console        Shooter                5              101.0                  13           14                    15  0.619000        5.690000       6.000000              0                    61                       0         1
# 25     P0026  19.0     EU       PC            RPG                4               59.0                  21           54                     1  0.512483        4.780000      13.000000              1                    31                       1         0
# 26     P0027  22.0    USA       PC  Battle Royale                5              116.0                  14           43                    28  0.509000        6.660000       5.000000              1                     5                       0         1
# 27     P0028  21.0   APAC       PC       Strategy                7               63.0                   3           59                     0  0.736000       28.420000       7.000000              0                     9                       1         0
# 28     P0029  24.0    USA   Mobile       Strategy                6              103.0                   4            9                    15  0.493000        9.020000      14.000000              1                    18                       1         0
# 29     P0030  36.0    USA       PC           MOBA                5               76.0                  23           42                    21  0.779000       11.850000      12.000000              0                    24                       0         0
# 30     P0031  23.0  LATAM  Console       Strategy                3               69.0                   1           26                     9  0.738000        3.130000       4.000000              0                     5                       1         1
# 31     P0032  36.0    USA   Mobile         Sports                6               99.0                  13           61                    38  0.480000       24.120000      13.000000              1                    16                       0         1
# 32     P0033  40.0    USA       PC           MOBA                4              105.0                   0           24                    28  0.507000       17.580000       6.000000              0                     2                       2         1
# 33     P0034  17.0    USA       PC        Shooter                3               67.0                   9           71                    29  0.733000       22.940000      18.000000              1                    43                       1         0
# 34     P0035  30.0   APAC       PC           MOBA                6              105.0                   9           35                    52  0.691000        9.710000       9.000000              1                    16                       2         0
# 35     P0036  32.0   APAC  Console        Shooter                4               94.0                   6            5                    27  0.560000        4.780000       1.000000              0                    30                       0         0
# 36     P0037  26.0    USA  Console         Sports                5               51.0                   4           15                    27  0.643000       13.220000       5.000000              0                    16                       0         0
# 37     P0038  37.0    USA       PC        Shooter                2               70.0                   8            1                    26  0.506000       19.280000       4.000000              1                    24                       1         0
# 38     P0039  16.0  LATAM       PC  Battle Royale                5               55.0                   8           40                    27  0.508000       17.120000      16.000000              0                    25                       0         0
# 39     P0040  18.0   APAC   Mobile            RPG                5               99.0                   1           36                    50  0.512483        3.330000       4.000000              0                     4                       1         0
# 40     P0041  27.0     EU  Console         Sports                3               45.0                   0           27                    23  0.826000       10.530000      10.000000              1                    41                       1         0
# 41     P0042  35.0     EU   Mobile       Strategy                6              122.0                   0           45                    18  0.427000        2.480000       3.000000              1                    15                       0         1
# 42     P0043  23.0     EU  Console           MOBA                5              510.0                   7           43                    40  0.585000       15.210000       0.000000              1                    53                       0         1
# 43     P0044  19.0    USA       PC       Strategy                5               10.0                   4           29                     5  0.620000       10.450000       7.000000              1                     7                       0         0
# 44     P0045  25.0     EU  Console  Battle Royale                8              124.0                  12           16                    63  0.409000       18.980000       5.000000              1                    40                       1         0
# 45     P0046  16.0     EU       PC           MOBA                5              114.0                   7           37                    19  0.588000        2.140000       9.000000              1                    16                       1         1
# 46     P0047  40.0    USA   Mobile  Battle Royale                3              122.0                  11           40                    38  0.831000        6.930000       0.000000              0                    33                       1         1
# 47     P0048  22.0     EU  Console         Sports                2              103.0                  10           27                    37  0.841000       26.920000       5.000000              0                    26                       0         1
# 48     P0049  19.0     EU       PC            RPG                8               85.0                   5           49                    47  0.433000        1.950000      11.000000              1                    10                       2         0
# 49     P0050  20.0     EU       PC  Battle Royale                2               57.0                   0           24                    39  0.532000        1.800000       6.000000              1                    16                       1         0
# 50     P0051  20.0     EU       PC         Sports                5               86.0                   9           14                     7  0.783000       16.000000       3.000000              1                    20                       1         1
# 51     P0052  37.0   APAC       PC  Battle Royale               10               88.0                   3           32                    44  0.413000        0.060000       2.000000              1                     2                       2         0
# 52     P0053  32.0   APAC       PC         Sports                4               77.0                   6           40                    10  0.542000        0.410000       7.589219              0                    13                       0         1
# 53     P0054  32.0     EU       PC  Battle Royale                4               47.0                  26           36                    28  0.496000        2.830000       7.000000              0                    23                       0         1
# 54     P0055  23.0   APAC  Console           MOBA                1               92.0                   9           67                     4  0.919000        8.250000       6.000000              0                    24                       0         1
# 55     P0056  25.0     EU   Mobile       Strategy                6               41.0                   5           33                    35  0.384000       12.910000      11.000000              0                     8                       0         1
# 56     P0057  18.0     EU       PC       Strategy                5               99.0                  14           46                    28  0.509000      999.000000       6.000000              0                     9                       0         1
# 57     P0058  16.0  LATAM  Console  Battle Royale                5               43.0                  14           31                    20  0.657000        3.600000      14.000000              0                     0                       1         1
# 58     P0059  17.0    USA       PC        Shooter                4               86.0                   9           17                    27  0.550000        2.410000      19.000000              1                     0                       1         0
# 59     P0060  28.0     EU  Console           MOBA                2               77.0                   0           44                    58  0.608000       21.250000       9.000000              1                    33                       1         1
# 60     P0061  36.0    USA       PC       Strategy                5               15.0                   5           38                     6  0.587000        5.920000       3.000000              1                     5                       0         0
# 61     P0062  17.0  LATAM       PC        Shooter                6               72.0                   7           14                    32  0.242000        2.120000       9.000000              1                    24                       0         0
# 62     P0063  17.0   APAC       PC           MOBA                4              119.0                   3           67                    38  0.416000       19.280000       2.000000              1                    33                       1         1
# 63     P0064  32.0     EU  Console  Battle Royale                4               90.0                   9           10                    33  0.592000       19.710000      14.000000              1                    34                       0         0
# 64     P0065  30.0     EU       PC  Battle Royale                4               78.0                   5           37                     9  0.891000        4.500000       9.000000              0                    14                       0         0
# 65     P0066  33.0    USA       PC         Sports                7               10.0                  17           58                    41  0.198000        7.870000       8.000000              0                    34                       1         0
# 66     P0067  19.0   APAC       PC        Shooter                3              101.0                  14           40                     7  0.588000        0.300000       8.000000              1                    34                       2         0
# 67     P0068  36.0  LATAM       PC         Sports               10               58.0                   3            7                    24  0.400000        8.870000       0.000000              1                    18                       2         1
# 68     P0069  30.0    USA   Mobile       Strategy                1               44.0                   0           47                    25  0.376000       14.381877       7.000000              1                    30                       0         1
# 69     P0070  23.0  LATAM  Console        Shooter                5               87.0                  10           79                    18  0.420000        2.990000      10.000000              0                    14                       0         0
# 70     P0071  32.0    USA       PC        Shooter               10               86.0                   0           38                     0  0.950000       67.310000       7.000000              1                    33                       1         1
# 71     P0072  20.0     EU       PC         Sports                3               65.0                  10           41                    37  0.802000        1.090000       0.000000              0                     6                       2         1
# 72     P0073  28.0     EU       PC         Sports                6               75.0                  21           49                    44  0.520000       15.890000      13.000000              0                    22                       0         1
# 73     P0074  28.0     EU       PC         Sports                6               96.0                  15           62                    18  0.572000       25.530000       7.000000              0                    23                       1         0
# 74     P0075  29.0   APAC   Mobile        Shooter                3               96.0                  12            1                    23  0.368000        0.110000       6.000000              0                    24                       0         1
# 75     P0076  17.0     EU       PC        Shooter                7               38.0                   9           42                    25  0.439000       14.780000       8.000000              0                    13                       1         1
# 76     P0077  30.0     EU       PC           MOBA                5               61.0                   7            1                    38  0.662000        7.080000       0.000000              0                     0                       2         1
# 77     P0078  29.0     EU  Console           MOBA                4               66.0                   0           24                    45  0.361000       16.440000       9.000000              1                    18                       1         0
# 78     P0079  29.0   APAC       PC           MOBA                4               45.0                   5           35                    18  0.641000       29.140000      16.000000              0                    40                       1         0
# 79     P0080  37.0    USA       PC            RPG                1               89.0                   3           52                    23  0.496000        0.900000       5.000000              1                     0                       0         0
# 80     P0081  16.0     EU   Mobile            RPG                6               96.0                   5           35                     5  0.487000       14.381877       8.000000              1                    12                       0         1
# 81     P0082  28.0    USA       PC  Battle Royale                6               50.0                  10           37                    53  0.707000       11.390000       9.000000              1                    19                       2         0
# 82     P0083  26.0  LATAM  Console           MOBA                5               98.0                   6           58                    34  0.827000       15.780000       4.000000              1                    16                       0         1
# 83     P0084  19.0     EU       PC  Battle Royale                6               84.0                   4           33                     8  0.680000        9.380000       3.000000              0                    21                       0         0
# 84     P0085  30.0  LATAM       PC            RPG                4               33.0                  10           46                    20  0.736000        5.090000       0.000000              1                    46                       3         0
# 85     P0086  34.0     EU  Console  Battle Royale                3               40.0                   3            1                    20  0.593000       17.950000      16.000000              1                     3                       1         0
# 86     P0087  21.0     EU  Console        Shooter                1               73.0                   6           54                     0  0.535000       10.790000       6.000000              1                     8                       0         0
# 87     P0088  16.0     EU       PC           MOBA                4               83.0                   7           43                    29  0.308000        4.930000       6.000000              0                    36                       2         0
# 88     P0089  40.0     EU       PC           MOBA                1              105.0                  18           38                    20  0.769000       14.381877       7.589219              0                    49                       1         1
# 89     P0090  16.0    USA       PC  Battle Royale                4               49.0                   6           43                    19  0.501000        1.930000      12.000000              1                    26                       1         1
# 90     P0091  28.0     EU  Console  Battle Royale                3               87.0                  12           20                    21  0.411000       39.680000      12.000000              1                     7                       1         1
# 91     P0092  23.0     EU  Console  Battle Royale                5               87.0                   9           30                    30  0.613000       33.940000      10.000000              1                    33                       1         0
# 92     P0093  24.0    USA       PC           MOBA                4               80.0                   3           29                    46  0.604000       31.190000      12.000000              1                    20                       1         0
# 93     P0094  37.0  LATAM       PC            RPG                2              104.0                  17           63                     0  0.661000        9.540000      13.000000              0                    48                       0         1
# 94     P0095  23.0    USA  Console            RPG                7              113.0                   0           22                    28  0.669000        7.830000       1.000000              1                     2                       2         1
# 95     P0096  33.0    USA       PC        Shooter                5              120.0                   6           57                    29  0.557000        5.740000       7.000000              0                     5                       0         0
# 96     P0097  36.0     EU  Console  Battle Royale                3               47.0                   9           60                    41  0.264000       15.110000       4.000000              0                     2                       0         0
# 97     P0098  25.0     EU       PC           MOBA                3               87.0                  14           23                    15  0.477000       20.300000      10.000000              0                     0                       0         1
# 98     P0099  36.0    USA       PC            RPG                4               85.0                  11           11                    45  0.455000       27.630000       1.000000              1                    13                       0         1
# 99     P0100  22.0   APAC   Mobile            RPG                3               81.0                   2           73                    10  0.546000       16.020000       6.000000              0                    27                       0         1
# 100    P0101  22.0     EU  Console  Battle Royale                1               81.0                  18            4                    32  0.500000        1.760000       3.000000              0                    41                       3         1
# 101    P0102  21.0  LATAM  Console       Strategy                1              600.0                   0           22                    19  0.470000        8.780000       9.000000              1                     3                       2         1
# 102    P0103  21.0    USA  Console  Battle Royale                4               61.0                   0           23                    15  0.524000       39.140000      14.000000              0                    30                       1         1
# 103    P0104  27.0     EU  Console           MOBA                7               44.0                   4            9                    29  0.617000       22.140000      19.000000              0                    26                       1         1
# 104    P0105  21.0     EU   Mobile       Strategy                4               64.0                   0            7                     9  0.392000        8.550000       5.000000              1                    31                       1         1
# 105    P0106  30.0    USA       PC  Battle Royale                5               72.0                  14           29                    32  0.548000       18.730000       7.589219              0                    19                       0         0
# 106    P0107  33.0     EU       PC       Strategy                5               88.0                   8           47                     0  0.467000       11.190000       5.000000              1                    33                       2         0
# 107    P0108  19.0  LATAM       PC         Sports                6               76.0                   0           23                     0  0.544000        1.340000       1.000000              1                    29                       1         0
# 108    P0109  34.0     EU       PC        Shooter                3               59.0                  19           33                     5  0.632000        6.750000       4.000000              0                    32                       2         1
# 109    P0110  20.0     EU  Console            RPG                1               97.0                  11           76                    12  0.469000       26.120000       1.000000              0                    19                       2         0
# 110    P0111  38.0     EU       PC           MOBA                3               10.0                   4           42                     5  0.528000        0.150000       3.000000              1                    21                       2         1
# 111    P0112  19.0  LATAM       PC       Strategy                4               88.0                  15           44                    43  0.548000        5.980000       9.000000              1                    13                       1         1
# 112    P0113  33.0    USA   Mobile  Battle Royale                9               59.0                  13           40                    47  0.734000        0.830000       2.000000              1                    22                       2         1
# 113    P0114  26.0     EU       PC       Strategy                7               89.0                   0           38                    31  0.497000       42.380000       2.000000              1                     0                       1         0
# 114    P0115  30.0     EU  Console            RPG                6               56.0                   0           62                    23  0.462000       11.450000      11.000000              1                    36                       0         1
# 115    P0116  36.0    USA       PC           MOBA                4               48.0                   7           16                    28  0.624000       11.500000       9.000000              0                    11                       1         0
# 116    P0117  33.0     EU       PC        Shooter                4               68.0                  10           49                    40  0.413000       23.710000      12.000000              1                    12                       4         0
# 117    P0118  26.0   APAC       PC           MOBA                5               32.0                   4           40                    18  0.541000       40.270000       2.000000              0                    21                       2         1
# 118    P0119  37.0  LATAM       PC  Battle Royale                8               90.0                  10           51                    18  0.572000        7.430000       6.000000              1                    11                       0         0
# 119    P0120  29.0   APAC  Console  Battle Royale                2               86.0                  16           24                    25  0.502000       17.180000       0.000000              0                     8                       1         0
# 120    P0121  19.0  LATAM       PC           MOBA                8               43.0                   3           47                    33  0.369000        0.020000       6.000000              0                    17                       2         1
# 121    P0122  20.0   APAC       PC           MOBA                8               76.0                  22           56                    43  0.589000        3.770000       7.000000              0                    37                       0         1
# 122    P0123  21.0   APAC       PC       Strategy                6               62.0                   0           41                    33  0.413000        3.230000       5.000000              1                    19                       2         0
# 123    P0124  21.0     EU   Mobile         Sports                7               89.0                   6           17                    22  0.663000       10.180000       1.000000              0                    26                       1         0
# 124    P0125  37.0   APAC   Mobile           MOBA                5               30.0                  10           32                    21  0.261000       14.381877       6.000000              1                    26                       1         0
# 125    P0126  19.0     EU   Mobile        Shooter                5               78.0                   4           28                    38  0.474000        7.670000       3.000000              1                    10                       2         1
# 126    P0127  28.0    USA       PC         Sports                4               56.0                   0           50                    39  0.458000        0.260000       9.000000              1                    23                       1         0
# 127    P0128  29.0     EU   Mobile         Sports                6               43.0                  10           10                    34  0.495000       11.250000       3.000000              0                    18                       0         0
# 128    P0129  22.0     EU   Mobile           MOBA                5              122.0                  15            1                    31  0.714000       11.390000      10.000000              0                    16                       0         0
# 129    P0130  40.0     EU  Console         Sports                4              125.0                  20           16                    17  0.511000        8.620000       7.000000              0                    38                       1         1
# 130    P0131  35.0     EU   Mobile            RPG                8               81.0                  10           19                    20  0.397000       35.170000      15.000000              1                    26                       1         0
# 131    P0132  27.0    USA  Console       Strategy                4              154.0                  10           21                    21  0.672000       17.930000       0.000000              1                    24                       2         0
# 132    P0133  31.0     EU  Console        Shooter                5               98.0                  22            2                    33  0.332000        5.410000      20.000000              0                    24                       1         0
# 133    P0134  20.0     EU       PC           MOBA                9               48.0                   8           60                    26  0.568000       49.710000      13.000000              0                    39                       2         0
# 134    P0135  40.0    USA       PC        Shooter                3               88.0                  10           33                     9  0.349000       30.040000       9.000000              1                    16                       2         0
# 135    P0136  37.0     EU  Console       Strategy                4               99.0                  11           19                    19  0.438000       14.381877      16.000000              1                    18                       1         1
# 136    P0137  26.0   APAC  Console  Battle Royale                4               91.0                   5           22                    35  0.349000       57.560000      12.000000              0                    17                       1         1
# 137    P0138  36.0     EU   Mobile           MOBA                6               79.0                  10           43                    37  0.666000        3.620000       9.000000              1                    29                       0         0
# 138    P0139  21.0     EU   Mobile        Shooter                3               41.0                   6           16                    26  0.712000        0.220000       5.000000              1                    21                       0         1
# 139    P0140  29.0    USA   Mobile       Strategy                5               82.0                  14           25                    37  0.442000        1.430000       9.000000              0                    44                       0         1
# 140    P0141  39.0  LATAM   Mobile       Strategy                6               76.0                  12           62                    22  0.619000        4.990000      14.000000              0                    23                       1         1
# 141    P0142  36.0     EU  Console       Strategy                3               75.0                  10           55                    31  0.596000       21.210000       8.000000              1                    34                       1         0
# 142    P0143  30.0     EU  Console       Strategy                4               52.0                   5           28                    26  0.595000       18.660000      15.000000              0                    35                       0         1
# 143    P0144  18.0   APAC   Mobile            RPG                5               78.0                  18           46                    62  0.516000        0.880000       4.000000              1                     6                       0         1
# 144    P0145  25.0    USA  Console            RPG                2               72.0                   0           48                    29  0.281000        0.070000      13.000000              1                    15                       1         0
# 145    P0146  24.0    USA       PC           MOBA                3               96.0                   8           58                    30  0.649000        0.360000       6.000000              1                    23                       1         0
# 146    P0147  34.0     EU  Console         Sports                6               70.0                  13           62                    41  0.419000       37.230000       5.000000              0                    23                       0         0
# 147    P0148  33.0  LATAM       PC  Battle Royale                6               44.0                  12           54                    30  0.377000        9.570000       6.000000              0                    32                       2         0
# 148    P0149  34.0    USA  Console        Shooter                4               75.0                  12           39                    42  0.543000       15.450000       8.000000              0                    13                       0         0
# 149    P0150  18.0     EU       PC  Battle Royale                3               72.0                  13           31                    19  0.593000        7.540000      13.000000              0                    17                       0         1
# 150    P0151  28.0  LATAM       PC         Sports                4              110.0                  11           43                     0  0.396000       10.470000      14.000000              1                     2                       1         0
# 151    P0152  20.0    USA       PC         Sports                4               78.0                   9            1                    47  0.425000       10.880000      14.000000              1                    23                       1         0
# 152    P0153  33.0   APAC       PC       Strategy                4               74.0                  11           35                    21  0.484000        0.380000       2.000000              0                    17                       2         0
# 153    P0154  28.0     EU       PC  Battle Royale                4               80.0                   9           51                     4  0.277000        4.990000       2.000000              1                    23                       3         0
# 154    P0155  28.0  LATAM  Console        Shooter                2               53.0                   8           43                    42  0.226000        1.800000      18.000000              1                    10                       3         1
# 155    P0156  34.0   APAC   Mobile       Strategy                4               43.0                   7           24                     5  0.536000       39.900000       9.000000              1                    27                       1         1
# 156    P0157  20.0     EU   Mobile           MOBA                3               96.0                   7           13                    27  0.512483       23.900000       0.000000              0                    37                       0         0
# 157    P0158  30.0     EU       PC         Sports                6               79.0                  17           20                    26  0.643000        7.030000      15.000000              1                    42                       2         0
# 158    P0159  32.0  LATAM   Mobile         Sports                6               10.0                  12           38                    27  0.442000       13.970000      12.000000              0                    35                       0         0
# 159    P0160  17.0    USA  Console           MOBA                7               53.0                  18           37                    46  0.284000        0.860000      10.000000              1                    27                       1         1
# 160    P0161  17.0  LATAM       PC         Sports                4               56.0                   3           32                    16  0.454000       19.820000       8.000000              0                    29                       0         0
# 161    P0162  25.0     EU  Console        Shooter                4               34.0                  11           21                    11  0.595000       23.890000       0.000000              0                    12                       0         1
# 162    P0163  22.0   APAC   Mobile        Shooter                1               71.0                   8           35                     3  0.680000       12.520000       0.000000              1                    24                       1         0
# 163    P0164  29.0   APAC       PC       Strategy                1               69.0                   0           16                    12  0.525000       29.840000       4.000000              0                    40                       3         1
# 164    P0165  40.0    USA       PC           MOBA                5               74.0                   5           37                    40  0.370000        4.560000       6.000000              0                    12                       1         1
# 165    P0166  30.0     EU       PC           MOBA                4               91.0                  12           31                    16  0.551000        0.520000      11.000000              1                    23                       1         0
# 166    P0167  26.0   APAC  Console  Battle Royale                5               76.0                   0           54                    31  0.457000       12.400000       7.000000              1                    16                       1         0
# 167    P0168  33.0    USA       PC         Sports                7               90.0                   9           11                    52  0.407000        5.570000       9.000000              1                    29                       2         0
# 168    P0169  23.0  LATAM   Mobile  Battle Royale                7               95.0                  15           10                    51  0.386000        2.670000       6.000000              0                    29                       0         1
# 169    P0170  25.0    USA       PC         Sports                3               77.0                   0           49                    30  0.512483        0.380000       3.000000              1                    36                       0         0
# 170    P0171  40.0   APAC   Mobile         Sports                5               88.0                   0           55                    38  0.608000        8.840000       6.000000              0                    24                       0         0
# 171    P0172  16.0    USA   Mobile       Strategy                3               93.0                  14           69                    56  0.618000        9.540000       9.000000              1                    31                       2         1
# 172    P0173  19.0     EU   Mobile         Sports                5               89.0                   9           46                    17  0.494000       13.360000       8.000000              0                    22                       2         0
# 173    P0174  37.0  LATAM       PC        Shooter                2               59.0                   5           29                    47  0.584000       10.360000       9.000000              1                    17                       1         0
# 174    P0175  32.0  LATAM       PC            RPG                4               85.0                  10           66                    30  0.443000       14.060000       7.000000              0                    31                       0         0
# 175    P0176  21.0     EU  Console           MOBA                1               79.0                  22           35                    25  0.446000       19.740000      18.000000              0                     0                       0         1
# 176    P0177  23.0     EU       PC           MOBA                5               84.0                   8           40                    21  0.257000       14.381877       8.000000              1                    14                       0         1
# 177    P0178  17.0  LATAM       PC         Sports                3              114.0                  15           29                    17  0.657000        3.170000       7.589219              1                    19                       4         1
# 178    P0179  25.0     EU  Console        Shooter                4               86.0                  17           36                    15  0.377000        6.190000      25.000000              1                     4                       1         1
# 179    P0180  18.0     EU  Console  Battle Royale                5               89.0                  16           24                    34  0.263000        5.330000       1.000000              0                    30                       1         1
# 180    P0181  26.0     EU       PC  Battle Royale                3               93.0                   0           47                    53  0.421000        9.940000       0.000000              1                    12                       0         1
# 181    P0182  38.0    USA       PC            RPG                7               64.0                   5            1                    34  0.301000        2.470000      12.000000              0                    16                       0         0
# 182    P0183  30.0     EU       PC         Sports                4              100.0                   3           56                    28  0.697000        7.470000       7.000000              1                    29                       2         0
# 183    P0184  40.0    USA   Mobile  Battle Royale                2               47.0                  12           14                    37  0.569000        6.590000       2.000000              1                     7                       1         1
# 184    P0185  30.0   APAC  Console            RPG                3              110.0                  20           52                    29  0.379000       14.830000      10.000000              1                    15                       1         1
# 185    P0186  19.0    USA       PC            RPG                5               87.0                   9           15                    38  0.644000        2.270000       7.000000              0                    27                       0         0
# 186    P0187  21.0  LATAM   Mobile       Strategy                5               87.0                  12           42                    40  0.407000        2.610000       1.000000              1                     7                       3         0
# 187    P0188  16.0     EU  Console           MOBA                4               25.0                   0           37                    22  0.545000       19.170000      13.000000              0                    26                       1         1
# ...
# 487    P0488  23.0   APAC       PC  Battle Royale                1               46.0                   9           53                    54  0.519000       10.410000      10.000000              0                    10                       2         1
# 488    P0489  35.0   APAC       PC  Battle Royale                3              101.0                   1           43                    16  0.558000        6.650000       7.589219              0                    11                       2         0
# 489    P0490  23.0  LATAM       PC            RPG                6               78.0                  18           37                    34  0.650000        4.960000      13.000000              0                    20                       1         0
# 490    P0491  20.0     EU  Console         Sports                5               75.0                   0           55                     0  0.478000       30.960000       8.000000              1                    17                       0         0
# 491    P0492  18.0     EU   Mobile        Shooter                3               89.0                  13           23                    57  0.420000        4.600000       8.000000              1                     2                       0         1
# 492    P0493  34.0     EU       PC            RPG                4               52.0                   8            6                    30  0.631000        5.250000       1.000000              1                     0                       3         0
# 493    P0494  40.0   APAC  Console       Strategy                3               68.0                  22           41                    26  0.686000        6.350000      11.000000              0                    11                       2         0
# 494    P0495  33.0     EU       PC        Shooter                7               48.0                   3           52                     0  0.478000        6.340000       5.000000              0                    17                       0         0
# 495    P0496  39.0  LATAM  Console            RPG                2              100.0                   0           10                    29  0.646000        9.410000       2.000000              1                    40                       0         1
# 496    P0497  26.0     EU       PC           MOBA                5               52.0                   6           86                    17  0.717000       34.800000      21.000000              1                    13                       0         0
# 497    P0498  28.0     EU   Mobile           MOBA                7               74.0                   7           68                    35  0.451000       10.330000       4.000000              1                    11                       0         1
# 498    P0499  39.0     EU       PC        Shooter                6               60.0                  16           50                    55  0.396000       11.270000       6.000000              1                    40                       1         0
# 499    P0500  37.0     EU   Mobile  Battle Royale                6               63.0                  10           43                    33  0.439000       17.600000       0.000000              0                    34                       0         0
# 500    P0501  21.0   APAC   Mobile  Battle Royale                8               95.0                   4           28                     9  0.695000        2.260000       9.000000              1                    15                       4         1
# 501    P0502  19.0     EU       PC  Battle Royale                3               65.0                  24           21                    26  0.432000       27.060000       1.000000              1                    22                       3         1
# 502    P0503  23.0     EU       PC           MOBA                4               26.0                  14           26                    43  0.308000        1.770000      10.000000              1                    25                       3         1
# 503    P0504  33.0     EU  Console  Battle Royale                5               61.0                   3           40                    29  0.617000        5.430000       3.000000              1                    32                       0         1
# 504    P0505  19.0   APAC       PC         Sports                4              102.0                   0           44                    42  0.407000        3.810000       3.000000              0                    30                       1         0
# 505    P0506  34.0     EU       PC       Strategy                7               66.0                   8            7                    19  0.668000       12.330000       5.000000              1                    18                       0         0
# 506    P0507  30.0     EU  Console            RPG                5              108.0                   7           23                    32  0.433000       19.670000       6.000000              1                     1                       1         1
# 507    P0508  27.0   APAC   Mobile           MOBA                7               91.0                   0           26                     7  0.672000       23.600000       7.000000              0                     9                       1         0
# 508    P0509  22.0    USA       PC         Sports                3               25.0                   0           69                    51  0.414000       13.900000       5.000000              1                    30                       1         0
# 509    P0510  38.0     EU       PC       Strategy                7               59.0                  11           40                    50  0.123000        6.450000       5.000000              0                    28                       1         0
# 510    P0511  26.0     EU       PC         Sports                6               68.0                  18           25                    23  0.429000       19.760000       5.000000              1                    38                       3         0
# 511    P0512  33.0   APAC   Mobile  Battle Royale                1               74.0                   0           23                    14  0.621000        2.260000       0.000000              1                    25                       0         0
# 512    P0513  40.0    USA       PC           MOBA                3               67.0                  12           26                    28  0.423000       10.050000       2.000000              1                    53                       0         1
# 513    P0514  24.0   APAC       PC            RPG                3              116.0                   6           52                    21  0.486000        9.610000       4.000000              0                    26                       1         0
# 514    P0515  33.0     EU  Console            RPG                6               53.0                   0            4                    24  0.348000        7.870000       0.000000              0                     5                       1         1
# 515    P0516  19.0    USA       PC  Battle Royale                2               89.0                  13           13                    22  0.456000        0.700000       5.000000              0                    30                       0         1
# 516    P0517  27.0   APAC       PC           MOBA                4               60.0                   8           48                    41  0.451000        6.030000       2.000000              0                    14                       1         1
# 517    P0518  39.0     EU       PC           MOBA                8               91.0                   6           18                    22  0.723000       35.210000      13.000000              1                    20                       4         0
# 518    P0519  34.0   APAC       PC           MOBA                2               49.0                  12           41                    23  0.613000        9.620000       3.000000              1                    18                       1         1
# 519    P0520  40.0   APAC   Mobile        Shooter                3               66.0                   0           28                    45  0.309000       15.730000      17.000000              0                    16                       1         0
# 520    P0521  28.0    USA       PC            RPG                7               68.0                  16           43                     9  0.714000       11.350000       2.000000              0                    37                       0         1
# 521    P0522  24.0     EU       PC            RPG                2               86.0                   0           42                    40  0.591000       19.130000      11.000000              0                    25                       2         0
# 522    P0523  27.0     EU       PC        Shooter                3               91.0                   7           27                     3  0.513000        1.600000      15.000000              1                    27                       4         0
# 523    P0524  18.0   APAC  Console           MOBA                1               54.0                  10           45                    27  0.674000        1.680000       3.000000              0                    29                       0         0
# 524    P0525  31.0     EU       PC         Sports                6              119.0                   6           12                    30  0.345000        6.100000       3.000000              0                    15                       2         0
